# %% [markdown]
# # Portfolio Analysis

# %% [markdown]
# This script is V2 version of my Portfolio Analysis script that takes my stock data and creates dataframes to provide detailed information on my portfolio. This update was made after the Robinhood API was updated and is no longer usable for me. The output of this script are the following CSV data files, that are then used for my Streamlit app.
# - Daily stock data --> this table will contain the daily prices of all the stocks I own and their quantities. It starts from the day I began investing on RobinHood (September 9th, 2016) until today (whenever that is). This table will be used to show my holdings over time with a focus on the profit/loss of my portfolio and specific stocks over time.
# - Current stock data --> this table will provide a single snapshot of my stock holdings today. It will be used to show the state of my portfolio as it is today.
# - Company information --> to complement these two tables above, I will also be using the RobinHood API to compile market information on these stocks that can be used to supplement my analysis.

# %% [markdown]
# ## Import Packages and Data

# %%
import ftplib
from io import StringIO
import json
import numpy as np
import pandas as pd
from tenacity import retry, stop_after_attempt, wait_fixed
import time
import yfinance as yf
# Out:
# /Users/brandoncroarkin/opt/anaconda3/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /Users/brandoncroarkin/opt/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %%
# Read in Stock Dictionary
with open('data/stock_dictionary.json', 'r') as stock_dictionary:
    stock_dictionary = json.load(stock_dictionary)

# %% [markdown]
# ## Create Needed Functions

# %%
def build_summary_dataframe(stock_dictionary):
    """
    Builds a summary DataFrame for stocks using a stock dictionary and Yahoo Finance.
    
    Returns:
        pd.DataFrame: A DataFrame with columns ordered as:
        Stock, Company, Price, Quantity, Avg_Cost, Market_Value, Percent_Change, Equity_Change, 52_Week_High, 52_Week_Low
    """
    stock_data = []

    for ticker, details in stock_dictionary.items():
        try:
            # Fetch stock data from Yahoo Finance
            stock = yf.Ticker(ticker)
            stock_info = stock.info
            splits = stock.splits

            if not splits.empty:
                splits.index = splits.index.tz_localize(None)

            # Extract required fields
            current_price = stock_info.get("currentPrice")
            company_name = stock_info.get("longName", details["stock_name"])
            percent_change = stock_info.get("52WeekChange", 0) * 100
            high_52_week = stock_info.get("fiftyTwoWeekHigh")
            low_52_week = stock_info.get("fiftyTwoWeekLow")

            # Initialize cumulative tracking variables
            total_quantity = 0
            total_cost = 0
            avg_cost = 0  # Track average cost

            # Combine transactions and splits into a single timeline
            events = []
            for transaction in details["purchase_history"]:
                transaction_date = pd.to_datetime(transaction["date"]).tz_localize(None)
                events.append({
                    "type": "transaction",
                    "date": transaction_date,
                    "transaction": transaction
                })
            for split_date, ratio in splits.items():
                split_date = pd.Timestamp(split_date).tz_localize(None)
                events.append({
                    "type": "split",
                    "date": split_date,
                    "ratio": ratio
                })

            # Sort events by date
            events = sorted(events, key=lambda x: x["date"])

            print(f"Processing {ticker}:")
            for event in events:
                if event["type"] == "transaction":
                    # Process transactions
                    transaction = event["transaction"]
                    transaction_date = event["date"]

                    if transaction["buy_sell"] == "buy":
                        new_quantity = int(transaction["quantity"])
                        new_cost = new_quantity * transaction["share_price"]
                        prev_avg_cost = avg_cost
                        total_quantity += new_quantity
                        total_cost += new_cost
                        avg_cost = total_cost / total_quantity
                        print(
                            f"Purchase on {transaction_date.date()} of {new_quantity} shares at {transaction['share_price']:.2f}. "
                            f"\nUpdated Quantity: {total_quantity}, Updated Avg Cost: {avg_cost:.2f} (Previous Avg Cost: {prev_avg_cost:.2f})\n"
                        )
                    elif transaction["buy_sell"] == "sell":
                        sell_quantity = transaction["quantity"]
                        if sell_quantity > total_quantity:
                            raise ValueError(f"Selling more shares than owned for {ticker} on {transaction_date}")
                        prev_quantity = total_quantity
                        total_quantity -= sell_quantity
                        total_cost -= sell_quantity * avg_cost  # Total cost decreases but avg_cost remains unchanged
                        print(
                            f"Sell on {transaction_date.date()} of {sell_quantity} shares at {transaction['share_price']:.2f}. "
                            f"\nUpdated Quantity: {total_quantity} (Previous Quantity: {prev_quantity}), Avg Cost remains {avg_cost:.2f}\n"
                        )
                elif event["type"] == "split":
                    # Process splits
                    split_date = event["date"]
                    ratio = event["ratio"]
                    if total_quantity > 0:  # Apply splits only if shares are owned
                        old_quantity = total_quantity
                        old_avg_cost = avg_cost
                        total_quantity *= ratio
                        avg_cost /= ratio
                        print(
                            f"Stock Split on {split_date.date()}: Ratio {ratio}. "
                            f"\nPrevious Quantity: {old_quantity}, Previous Avg Cost: {old_avg_cost:.2f} "
                            f"\nUpdated Quantity: {total_quantity}, Updated Avg Cost: {avg_cost:.2f}\n"
                        )

            market_value = total_quantity * current_price if current_price else 0
            equity_change = market_value - total_cost if market_value else None

            # Append stock summary
            stock_data.append([
                ticker,
                company_name,
                current_price,
                total_quantity,
                avg_cost,
                market_value,
                percent_change,
                equity_change,
                high_52_week,
                low_52_week
            ])

        except Exception as e:
            print(f"Error fetching data for {ticker}: {e}")

    # Create DataFrame
    stocks_df = pd.DataFrame(
        stock_data,
        columns=[
            "Stock",
            "Company",
            "Price",
            "Quantity",
            "Avg_Cost",
            "Market_Value",
            "Percent_Change",
            "Equity_Change",
            "52_Week_High",
            "52_Week_Low",
        ],
    )
    
    # Add in a column for portfolio diversity to stocks
    stocks_df['Portfolio_Diversity'] = round(stocks_df['Market_Value'] * 100/ sum(stocks_df['Market_Value']),2)
    # Add in column for the overall direction of the stock movement
    stocks_df['Direction'] = np.where(stocks_df['Percent_Change'] > 0, 'Up', 'Down')
    
    # Filter to just the stocks that I currently own
    filtered_stocks = stocks_df[stocks_df["Quantity"] > 0]
    
    # Format the DF
    filtered_stocks['Price'] = round(filtered_stocks['Price'],2)
    filtered_stocks['Quantity'] = round(filtered_stocks['Quantity'],2)
    filtered_stocks['Avg_Cost'] = round(filtered_stocks['Avg_Cost'],2)
    filtered_stocks['Market_Value'] = round(filtered_stocks['Market_Value'],2)
    filtered_stocks['Percent_Change'] = round(filtered_stocks['Percent_Change'],2)
    filtered_stocks['Equity_Change'] = round(filtered_stocks['Equity_Change'],2)
    filtered_stocks['52_Week_High'] = round(filtered_stocks['52_Week_High'],2)
    filtered_stocks['52_Week_Low'] = round(filtered_stocks['52_Week_Low'],2)

    # Sort the dataframe by the Market Value (desc)
    sorted_stocks = filtered_stocks.sort_values(by="Market_Value", ascending=False)

    return sorted_stocks

# %%
def format_seconds(seconds):
    minutes, sec = divmod(int(seconds), 60)
    hours, min_ = divmod(minutes, 60)
    return f"{hours:02d}:{min_:02d}:{sec:02d}"

# %%
def create_daily_stock_table(stock_dictionary, start_date="2016-01-01"):
    """
    Creates a detailed table of daily stock values for all stock positions.

    Returns:
        pd.DataFrame: A DataFrame with columns ordered as:
        Date, Close, Stock, Shares_Held, Avg_Cost, Equity, Market_Value, Total_Profit, Daily_Profit, Daily_Pct_Profit
    """
    daily_data = []

    for ticker, details in stock_dictionary.items():
        try:
            stock = yf.Ticker(ticker)
            historical_data = stock.history(start=start_date)
            historical_data.reset_index(inplace=True)
            historical_data["Date"] = historical_data["Date"].dt.tz_localize(None)

            total_quantity = 0
            total_cost = 0
            for transaction in details["purchase_history"]:
                transaction_date = pd.to_datetime(transaction["date"]).tz_localize(None)
                if transaction["buy_sell"] == "buy":
                    total_quantity += transaction["quantity"]
                    total_cost += transaction["quantity"] * transaction["share_price"]
                elif transaction["buy_sell"] == "sell":
                    total_quantity -= transaction["quantity"]
                    total_cost -= transaction["quantity"] * transaction["share_price"]

            avg_cost = total_cost / total_quantity if total_quantity > 0 else 0
            historical_data["Stock"] = ticker
            historical_data["Shares_Held"] = total_quantity
            historical_data["Avg_Cost"] = avg_cost
            historical_data["Equity"] = historical_data["Shares_Held"] * historical_data["Avg_Cost"]
            historical_data["Market_Value"] = historical_data["Shares_Held"] * historical_data["Close"]
            historical_data["Total_Profit"] = historical_data["Market_Value"] - historical_data["Equity"]
            historical_data["Daily_Profit"] = historical_data["Total_Profit"].diff().fillna(0)
            historical_data["Daily_Pct_Profit"] = historical_data["Close"].pct_change().fillna(0) * 100

            daily_data.append(
                historical_data[
                    [
                        "Date",
                        "Close",
                        "Stock",
                        "Shares_Held",
                        "Avg_Cost",
                        "Equity",
                        "Market_Value",
                        "Total_Profit",
                        "Daily_Profit",
                        "Daily_Pct_Profit",
                    ]
                ]
            )

        except Exception as e:
            print(f"Error fetching data for {ticker}: {e}")
            
    # Format list as a df
    daily_stocks_df = pd.concat(daily_data, ignore_index=True)

    # Format the df values
    daily_stocks_df['Close'] = round(daily_stocks_df['Close'],2)
    daily_stocks_df['Avg_Cost'] = round(daily_stocks_df['Avg_Cost'],2)
    daily_stocks_df['Market_Value'] = round(daily_stocks_df['Market_Value'],2)
    daily_stocks_df['Equity'] = round(daily_stocks_df['Equity'],2)
    daily_stocks_df['Total_Profit'] = round(daily_stocks_df['Total_Profit'],2)
    daily_stocks_df['Daily_Profit'] = round(daily_stocks_df['Daily_Profit'],2)
    daily_stocks_df['Daily_Pct_Profit'] = round(daily_stocks_df['Daily_Pct_Profit'],2)
    
    # Return the df
    return daily_stocks_df

# %%
def categorize_market_cap(market_cap_b):
    """
    Categorize companies based on market capitalization (in Billions).
    
    Categories:
    - Mega (>$200B)
    - Large ($10B-$200B)
    - Medium ($2B-$10B)
    - Small ($300M-$2B)
    - Micro ($50M-$300M)
    - Nano (<$50M)
    
    :param market_cap_b: Market capitalization in billions
    :return: Market cap category as a string
    """
    if pd.isna(market_cap_b) or market_cap_b <= 0:
        return "Unknown"

    if market_cap_b >= 200:
        return "Mega"
    elif 10 <= market_cap_b < 200:
        return "Large"
    elif 2 <= market_cap_b < 10:
        return "Medium"
    elif 0.3 <= market_cap_b < 2:
        return "Small"
    elif 0.05 <= market_cap_b < 0.3:
        return "Micro"
    else:
        return "Nano"

# %%
def create_stock_info_table(stock_tickers, delay=1.5, limit=None):
    """
    Creates a stock information table with a time delay between requests to prevent Yahoo Finance's rate limit.
    Includes runtime progress updates.
    
    Notes:
        - Market_Cap value is in unit of Billions $

    Args:
        stock_tickers (list): A list of unique stock tickers to pull information for from Yahoo Finance.
        delay (float): Time delay (seconds) between requests. Default: 1.5
        limit (int): Limit number of tickers for testing. Default: None

    Returns:
        pd.DataFrame: Stock information with valuation, fundamentals, and metadata.
    """
    # Limit tickers if specified
    if limit:
        stock_tickers = stock_tickers[:limit]

    stock_info_data = []
    total = len(stock_tickers)
    start_time = time.time()

    for i, ticker in enumerate(stock_tickers, start=1):
        print(f"[{i}/{total}] Fetching data for: {ticker}")
        try:
            stock = yf.Ticker(ticker)
            stock_info = stock.info

            company_name = stock_info.get("longName")
            officers = stock_info.get("companyOfficers", [])
            ceo_name = officers[0].get("name", "N/A") if officers and isinstance(officers[0], dict) else "N/A"
            country = stock_info.get("country", "N/A")
            state = stock_info.get("state", "N/A")
            city = stock_info.get("city", "N/A")
            market_cap = stock_info.get("marketCap", np.nan)
            if market_cap:
                market_cap = market_cap / 1e9  # billions

            # Retrieve financials
            stock_info_data.append([
                ticker,
                company_name,
                ceo_name,
                country,
                state,
                city,
                market_cap,
                stock_info.get("enterpriseValue"),
                stock_info.get("ebitda"),
                stock_info.get("totalRevenue"),
                stock_info.get("profitMargins"),
                stock_info.get("operatingMargins"),
                stock_info.get("returnOnAssets"),
                stock_info.get("returnOnEquity"),
                stock_info.get("debtToEquity"),
                stock_info.get("freeCashflow"),
                stock_info.get("averageVolume"),
                stock_info.get("sharesOutstanding"),
                stock_info.get("shortPercentOfFloat"),
                stock_info.get("heldPercentInstitutions"),
                stock_info.get("trailingPE"),
                stock_info.get("priceToBook"),
                stock_info.get("dividendYield"),
                stock_info.get("payoutRatio"),
                stock_info.get("exDividendDate"),
                stock_info.get("beta"),
                stock_info.get("sector", "N/A"),
                stock_info.get("industry", "N/A"),
                stock_info.get("targetHighPrice", "N/A"),
                stock_info.get("targetLowPrice", "N/A"),
                stock_info.get("targetMeanPrice", "N/A"),
                stock_info.get("targetMedianPrice", "N/A"),
                stock_info.get("recommendationMean", "N/A"),
                stock_info.get("recommendationKey", "N/A"),
                stock_info.get("numberOfAnalystOpinions", "N/A"),
                stock_info.get("longBusinessSummary", "N/A")
            ])

        except Exception as e:
            print(f"Error fetching data for {ticker}: {e}")

        # Progress updates
        if i in [int(total * 0.25), int(total * 0.5), int(total * 0.75)] or i == total:
            elapsed = time.time() - start_time
            estimated_total = (elapsed / i) * total
            remaining = estimated_total - elapsed
            pct = round((i / total) * 100)
        
            print(
                f"✅ {pct}% complete | "
                f"Elapsed: {format_seconds(elapsed)} | "
                f"Estimated remaining: {format_seconds(remaining)}"
            )

        # Delay to avoid rate-limiting
        time.sleep(delay)

    # Build DataFrame
    stocks_info_df = pd.DataFrame(
        stock_info_data,
        columns=[
            "Stock", "Company", "CEO", "Country", "State", "City", "Market_Cap", "Enterprise_Value",
            "EBITDA", "Revenue", "Profit_Margins", "Operating_Margins", "Return_On_Assets", 
            "Return_On_Equity", "Debt_To_Equity", "Free_Cashflow", "Avg_Volume",
            "Shares_Outstanding", "Short_Interest", "Institutional_Holdings", "PE_Ratio", "PB_Ratio", 
            "Dividend_Yield", "Payout_Ratio", "Dividend_Ex_Date", "Beta", "Sector",
            "Industry", "Target_High_Price", "Target_Low_Price", "Target_Mean_Price", "Target_Median_Price",
            "Recommendation_Mean", "Recommendation_Key", "No_Analysts", "Description"
        ]
    )

    # Add Market Cap Category
    stocks_info_df["Market_Cap_Category"] = stocks_info_df["Market_Cap"].apply(categorize_market_cap)

    # Sector reclassification
    stocks_info_df.loc[stocks_info_df["Stock"] == "O", "Sector"] = "Real Estate Investment Trusts"
    stocks_info_df.loc[stocks_info_df["Stock"] == "AFCG", "Sector"] = "Real Estate Investment Trusts"
    stocks_info_df.loc[stocks_info_df["Stock"] == "PLD", "Sector"] = "Real Estate Investment Trusts"
    stocks_info_df.loc[stocks_info_df["Stock"] == "V", "Sector"] = "Finance"

    print("🎉 Stock info table creation complete.\n")
    return stocks_info_df

# %%
def fetch_nasdaq_tickers():
    """
    Fetches stock tickers from the NASDAQ index.

    Returns:
        nasdaq_tickers (set): A set of unique stock tickers.
    """
    # Connect to the FTP server
    ftp = ftplib.FTP('ftp.nasdaqtrader.com')
    ftp.login()  # Anonymous login

    # Navigate to the directory containing the file
    ftp.cwd('/SymbolDirectory')

    # Retrieve the file
    r = []
    ftp.retrlines('RETR nasdaqlisted.txt', r.append)
    ftp.quit()

    # Join the lines and create a StringIO object
    data = '\n'.join(r)
    data_io = StringIO(data)

    # Read the data into a pandas DataFrame
    df = pd.read_csv(data_io, sep='|')

    # Filter out entries where the symbol is not available
    df = df[df['Symbol'].notna()]

    # Extract the list of NASDAQ tickers
    nasdaq_tickers = df['Symbol'].tolist()

    return nasdaq_tickers

# %%
def fetch_sp500_tickers():
    """
    Fetches stock tickers from the S&P 500 index.

    Returns:
        sp500_tickers (set): A set of unique stock tickers.
    """
    # Fetch S&P 500 tickers
    sp500_url = 'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies'
    sp500_table = pd.read_html(sp500_url, header=0)[0]
    sp500_tickers = sp500_table['Symbol'].tolist()

    return sp500_tickers

# %%
def rank_within_industry(df, column):
    """Ranks stocks within their industry for a given column (higher values are better)."""
    df[column + '_Rank'] = df.groupby('Industry')[column].rank(ascending=False, pct=True)
    return df

# %% [markdown]
# ## Build Stock Tables

# %% [markdown]
# ### Stock Summary DF

# %%
ticker = "MTCH"
splits = yf.Ticker(ticker).splits
if not splits.empty:
    splits.index = splits.index.tz_localize(None)
    print(f"Splits for {ticker}: {splits}")
# Out:
# Splits for MTCH: Date
# 1998-03-27    2.000
# 2000-02-25    2.000
# 2005-08-09    0.900
# 2008-08-21    1.146
# 2020-07-01    3.502
# Name: Stock Splits, dtype: float64

# %%
test_stock_dictionary = {
    "NVDA": {"stock_name": "NVIDIA", "purchase_history": [{"date": "3/2/2017", "buy_sell": "buy", "quantity": 1, "share_price": 129.39}]},
    "TSLA": {"stock_name": "Tesla", "purchase_history": [{"date": "2017-10-04", "buy_sell": "buy", "quantity": 5, "share_price": 356.85}]},
}
build_summary_dataframe(test_stock_dictionary)
# Out:
# Processing NVDA:
# Purchase on 2017-03-02 of 1 shares at 129.39.
# Updated Quantity: 1, Updated Avg Cost: 129.39 (Previous Avg Cost: 0.00)
#
# Stock Split on 2021-07-20: Ratio 4.0.
# Previous Quantity: 1, Previous Avg Cost: 129.39
# Updated Quantity: 4.0, Updated Avg Cost: 32.35
#
# Stock Split on 2024-06-10: Ratio 10.0.
# Previous Quantity: 4.0, Previous Avg Cost: 32.35
# Updated Quantity: 40.0, Updated Avg Cost: 3.23
#
# Processing TSLA:
# Purchase on 2017-10-04 of 5 shares at 356.85.
# Updated Quantity: 5, Updated Avg Cost: 356.85 (Previous Avg Cost: 0.00)
#
# Stock Split on 2020-08-31: Ratio 5.0.
# Previous Quantity: 5, Previous Avg Cost: 356.85
# Updated Quantity: 25.0, Updated Avg Cost: 71.37
#
# Stock Split on 2022-08-25: Ratio 3.0.
# Previous Quantity: 25.0, Previous Avg Cost: 71.37
# Updated Quantity: 75.0, Updated Avg Cost: 23.79
#   Stock             Company   Price  Quantity  Avg_Cost  Market_Value  \
# 1  TSLA         Tesla, Inc.  252.31      75.0     23.79      18923.25
# 0  NVDA  NVIDIA Corporation  110.93      40.0      3.23       4437.20
#
#    Percent_Change  Equity_Change  52_Week_High  52_Week_Low  \
# 1           56.25       17139.00        488.54       138.80
# 0           28.99        4307.81        153.13        75.61
#
#    Portfolio_Diversity Direction
# 1                81.01        Up
# 0                18.99        Up

# %%
# Create Stock Summary df
stock_summary_df = build_summary_dataframe(stock_dictionary)
# Out:
# Processing TSLA:
# Purchase on 2016-09-21 of 2 shares at 204.15.
# Updated Quantity: 2, Updated Avg Cost: 204.15 (Previous Avg Cost: 0.00)
#
# Sell on 2017-08-21 of 2 shares at 342.45.
# Updated Quantity: 0 (Previous Quantity: 2), Avg Cost remains 204.15
#
# Purchase on 2017-10-04 of 5 shares at 356.85.
# Updated Quantity: 5, Updated Avg Cost: 356.85 (Previous Avg Cost: 204.15)
#
# Stock Split on 2020-08-31: Ratio 5.0.
# Previous Quantity: 5, Previous Avg Cost: 356.85
# Updated Quantity: 25.0, Updated Avg Cost: 71.37
#
# Stock Split on 2022-08-25: Ratio 3.0.
# Previous Quantity: 25.0, Previous Avg Cost: 71.37
# Updated Quantity: 75.0, Updated Avg Cost: 23.79
#
# Sell on 2024-12-24 of 2 shares at 451.75.
# Updated Quantity: 73.0 (Previous Quantity: 75.0), Avg Cost remains 23.79
#
# Sell on 2025-01-02 of 73 shares at 423.05.
# Updated Quantity: 0.0 (Previous Quantity: 73.0), Avg Cost remains 23.79
#
# Processing HBI:
# Purchase on 2019-03-11 of 3 shares at 17.90.
# Updated Quantity: 3, Updated Avg Cost: 17.90 (Previous Avg Cost: 0.00)
#
# Sell on 2021-08-01 of 3 shares at 18.42.
# Updated Quantity: 0 (Previous Quantity: 3), Avg Cost remains 17.90
#
# Processing INTC:
# Purchase on 2019-03-11 of 1 shares at 53.35.
# Updated Quantity: 1, Updated Avg Cost: 53.35 (Previous Avg Cost: 0.00)
#
# Sell on 2022-08-25 of 1 shares at 34.63.
# Updated Quantity: 0 (Previous Quantity: 1), Avg Cost remains 53.35
#
# Purchase on 2025-01-23 of 25 shares at 21.39.
# Updated Quantity: 25, Updated Avg Cost: 21.39 (Previous Avg Cost: 53.35)
#
# Processing SBUX:
# Purchase on 2018-12-07 of 1 shares at 66.24.
# Updated Quantity: 1, Updated Avg Cost: 66.24 (Previous Avg Cost: 0.00)
#
# Purchase on 2022-10-18 of 4 shares at 94.13.
# Updated Quantity: 5, Updated Avg Cost: 88.55 (Previous Avg Cost: 66.24)
#
# Purchase on 2022-10-18 of 4 shares at 92.50.
# Updated Quantity: 9, Updated Avg Cost: 90.31 (Previous Avg Cost: 88.55)
#
# Sell on 2022-10-18 of 9 shares at 98.80.
# Updated Quantity: 0 (Previous Quantity: 9), Avg Cost remains 90.31
#
# Processing BABA:
# Purchase on 2017-02-15 of 1 shares at 101.02.
# Updated Quantity: 1, Updated Avg Cost: 101.02 (Previous Avg Cost: 0.00)
#
# Sell on 2023-04-10 of 1 shares at 102.01.
# Updated Quantity: 0 (Previous Quantity: 1), Avg Cost remains 101.02
#
# Processing SNAP:
# Purchase on 2017-03-02 of 1 shares at 25.84.
# Updated Quantity: 1, Updated Avg Cost: 25.84 (Previous Avg Cost: 0.00)
#
# Sell on 2022-12-05 of 1 shares at 10.42.
# Updated Quantity: 0 (Previous Quantity: 1), Avg Cost remains 25.84
#
# Processing EA:
# Purchase on 2017-03-02 of 1 shares at 107.80.
# Updated Quantity: 1, Updated Avg Cost: 107.80 (Previous Avg Cost: 0.00)
#
# Sell on 2022-08-25 of 1 shares at 127.09.
# Updated Quantity: 0 (Previous Quantity: 1), Avg Cost remains 107.80
#
# Processing NVDA:
# Purchase on 2017-03-02 of 1 shares at 129.39.
# Updated Quantity: 1, Updated Avg Cost: 129.39 (Previous Avg Cost: 0.00)
#
# Stock Split on 2021-07-20: Ratio 4.0.
# Previous Quantity: 1, Previous Avg Cost: 129.39
# Updated Quantity: 4.0, Updated Avg Cost: 32.35
#
# Stock Split on 2024-06-10: Ratio 10.0.
# Previous Quantity: 4.0, Previous Avg Cost: 32.35
# Updated Quantity: 40.0, Updated Avg Cost: 3.23
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/SPWR?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=SPWR&crumb=5xFoDikwWRb
# Error fetching data for SPWR: 'NoneType' object has no attribute 'update'
# Processing LMT:
# Purchase on 2017-03-10 of 1 shares at 271.33.
# Updated Quantity: 1, Updated Avg Cost: 271.33 (Previous Avg Cost: 0.00)
#
# Sell on 2022-08-25 of 1 shares at 433.59.
# Updated Quantity: 0 (Previous Quantity: 1), Avg Cost remains 271.33
#
# Processing META:
# Purchase on 2017-05-25 of 1 shares at 150.59.
# Updated Quantity: 1, Updated Avg Cost: 150.59 (Previous Avg Cost: 0.00)
#
# Purchase on 2017-10-04 of 2 shares at 170.07.
# Updated Quantity: 3, Updated Avg Cost: 163.58 (Previous Avg Cost: 150.59)
#
# Sell on 2021-10-25 of 3 shares at 322.00.
# Updated Quantity: 0 (Previous Quantity: 3), Avg Cost remains 163.58
#
# Processing JD:
# Purchase on 2017-11-10 of 1 shares at 39.38.
# Updated Quantity: 1, Updated Avg Cost: 39.38 (Previous Avg Cost: 0.00)
#
# Sell on 2022-08-25 of 1 shares at 64.89.
# Updated Quantity: 0 (Previous Quantity: 1), Avg Cost remains 39.38
#
# Processing BZUN:
# Purchase on 2018-06-12 of 1 shares at 66.62.
# Updated Quantity: 1, Updated Avg Cost: 66.62 (Previous Avg Cost: 0.00)
#
# Purchase on 2018-11-01 of 1 shares at 40.58.
# Updated Quantity: 2, Updated Avg Cost: 53.60 (Previous Avg Cost: 66.62)
#
# Purchase on 2020-04-14 of 5 shares at 30.97.
# Updated Quantity: 7, Updated Avg Cost: 37.44 (Previous Avg Cost: 53.60)
#
# Sell on 2023-04-10 of 7 shares at 5.21.
# Updated Quantity: 0 (Previous Quantity: 7), Avg Cost remains 37.44
#
# Processing NKE:
# Purchase on 2018-09-06 of 1 shares at 80.50.
# Updated Quantity: 1, Updated Avg Cost: 80.50 (Previous Avg Cost: 0.00)
#
# Purchase on 2022-11-07 of 3 shares at 93.91.
# Updated Quantity: 4, Updated Avg Cost: 90.56 (Previous Avg Cost: 80.50)
#
# Purchase on 2023-09-05 of 1 shares at 100.61.
# Updated Quantity: 5, Updated Avg Cost: 92.57 (Previous Avg Cost: 90.56)
#
# Purchase on 2023-09-25 of 1 shares at 90.35.
# Updated Quantity: 6, Updated Avg Cost: 92.20 (Previous Avg Cost: 92.57)
#
# Purchase on 2023-10-12 of 3 shares at 99.24.
# Updated Quantity: 9, Updated Avg Cost: 94.55 (Previous Avg Cost: 92.20)
#
# Purchase on 2024-03-18 of 3 shares at 99.33.
# Updated Quantity: 12, Updated Avg Cost: 95.74 (Previous Avg Cost: 94.55)
#
# Purchase on 2024-07-10 of 3 shares at 71.84.
# Updated Quantity: 15, Updated Avg Cost: 90.96 (Previous Avg Cost: 95.74)
#
# Purchase on 2024-12-02 of 5 shares at 78.73.
# Updated Quantity: 20, Updated Avg Cost: 87.90 (Previous Avg Cost: 90.96)
#
# Purchase on 2025-02-10 of 10 shares at 69.13.
# Updated Quantity: 30, Updated Avg Cost: 81.65 (Previous Avg Cost: 87.90)
#
# Purchase on 2025-04-03 of 5 shares at 57.36.
# Updated Quantity: 35, Updated Avg Cost: 78.18 (Previous Avg Cost: 81.65)
#
# Processing FSLR:
# Purchase on 2017-05-02 of 1 shares at 29.69.
# Updated Quantity: 1, Updated Avg Cost: 29.69 (Previous Avg Cost: 0.00)
#
# Purchase on 2017-07-19 of 1 shares at 46.35.
# Updated Quantity: 2, Updated Avg Cost: 38.02 (Previous Avg Cost: 29.69)
#
# Sell on 2017-08-23 of 2 shares at 46.47.
# Updated Quantity: 0 (Previous Quantity: 2), Avg Cost remains 38.02
#
# Purchase on 2019-09-19 of 1 shares at 67.39.
# Updated Quantity: 1, Updated Avg Cost: 67.39 (Previous Avg Cost: 38.02)
#
# Purchase on 2020-04-14 of 5 shares at 41.70.
# Updated Quantity: 6, Updated Avg Cost: 45.98 (Previous Avg Cost: 67.39)
#
# Purchase on 2024-02-05 of 2 shares at 139.26.
# Updated Quantity: 8, Updated Avg Cost: 69.30 (Previous Avg Cost: 45.98)
#
# Processing UBER:
# Purchase on 2019-05-10 of 2 shares at 42.00.
# Updated Quantity: 2, Updated Avg Cost: 42.00 (Previous Avg Cost: 0.00)
#
# Purchase on 2019-11-05 of 2 shares at 29.11.
# Updated Quantity: 4, Updated Avg Cost: 35.55 (Previous Avg Cost: 42.00)
#
# Purchase on 2022-09-21 of 3 shares at 30.69.
# Updated Quantity: 7, Updated Avg Cost: 33.47 (Previous Avg Cost: 35.55)
#
# Purchase on 2022-09-22 of 1 shares at 28.01.
# Updated Quantity: 8, Updated Avg Cost: 32.79 (Previous Avg Cost: 33.47)
#
# Purchase on 2022-11-21 of 3 shares at 28.69.
# Updated Quantity: 11, Updated Avg Cost: 31.67 (Previous Avg Cost: 32.79)
#
# Purchase on 2022-12-19 of 5 shares at 25.65.
# Updated Quantity: 16, Updated Avg Cost: 29.79 (Previous Avg Cost: 31.67)
#
# Purchase on 2024-05-20 of 5 shares at 64.60.
# Updated Quantity: 21, Updated Avg Cost: 38.08 (Previous Avg Cost: 29.79)
#
# Purchase on 2024-12-10 of 15 shares at 65.03.
# Updated Quantity: 36, Updated Avg Cost: 49.31 (Previous Avg Cost: 38.08)
#
# Processing NSRGY:
# Purchase on 2019-08-20 of 1 shares at 110.11.
# Updated Quantity: 1, Updated Avg Cost: 110.11 (Previous Avg Cost: 0.00)
#
# Sell on 2019-08-20 of 1 shares at 110.40.
# Updated Quantity: 0 (Previous Quantity: 1), Avg Cost remains 110.11
#
# Processing PTON:
# Purchase on 2019-09-30 of 1 shares at 25.66.
# Updated Quantity: 1, Updated Avg Cost: 25.66 (Previous Avg Cost: 0.00)
#
# Sell on 2019-09-30 of 1 shares at 8.89.
# Updated Quantity: 0 (Previous Quantity: 1), Avg Cost remains 25.66
#
# Processing APPN:
# Purchase on 2019-11-25 of 1 shares at 42.27.
# Updated Quantity: 1, Updated Avg Cost: 42.27 (Previous Avg Cost: 0.00)
#
# Sell on 2023-04-10 of 1 shares at 41.28.
# Updated Quantity: 0 (Previous Quantity: 1), Avg Cost remains 42.27
#
# Processing MTCH:
# Purchase on 2019-11-25 of 1 shares at 69.76.
# Updated Quantity: 1, Updated Avg Cost: 69.76 (Previous Avg Cost: 0.00)
#
# Purchase on 2020-02-19 of 1 shares at 76.74.
# Updated Quantity: 2, Updated Avg Cost: 73.25 (Previous Avg Cost: 69.76)
#
# Stock Split on 2020-07-01: Ratio 3.502.
# Previous Quantity: 2, Previous Avg Cost: 73.25
# Updated Quantity: 7.004, Updated Avg Cost: 20.92
#
# Purchase on 2023-03-27 of 3 shares at 40.50.
# Updated Quantity: 10.004, Updated Avg Cost: 26.79 (Previous Avg Cost: 20.92)
#
# Purchase on 2023-03-27 of 5 shares at 36.52.
# Updated Quantity: 15.004, Updated Avg Cost: 30.03 (Previous Avg Cost: 26.79)
#
# Purchase on 2024-05-07 of 5 shares at 29.45.
# Updated Quantity: 20.003999999999998, Updated Avg Cost: 29.89 (Previous Avg Cost: 30.03)
#
# Processing WDAY:
# Purchase on 2019-11-25 of 1 shares at 176.38.
# Updated Quantity: 1, Updated Avg Cost: 176.38 (Previous Avg Cost: 0.00)
#
# Purchase on 2020-04-14 of 1 shares at 150.76.
# Updated Quantity: 2, Updated Avg Cost: 163.57 (Previous Avg Cost: 176.38)
#
# Purchase on 2020-06-03 of 1 shares at 210.39.
# Updated Quantity: 3, Updated Avg Cost: 179.18 (Previous Avg Cost: 163.57)
#
# Processing TWLO:
# Purchase on 2019-11-25 of 1 shares at 103.80.
# Updated Quantity: 1, Updated Avg Cost: 103.80 (Previous Avg Cost: 0.00)
#
# Processing V:
# Purchase on 2020-01-14 of 1 shares at 196.16.
# Updated Quantity: 1, Updated Avg Cost: 196.16 (Previous Avg Cost: 0.00)
#
# Purchase on 2020-04-14 of 1 shares at 174.34.
# Updated Quantity: 2, Updated Avg Cost: 185.25 (Previous Avg Cost: 196.16)
#
# Purchase on 2022-10-14 of 1 shares at 184.33.
# Updated Quantity: 3, Updated Avg Cost: 184.94 (Previous Avg Cost: 185.25)
#
# Purchase on 2023-10-18 of 1 shares at 238.67.
# Updated Quantity: 4, Updated Avg Cost: 198.38 (Previous Avg Cost: 184.94)
#
# Processing JNJ:
# Purchase on 2020-04-08 of 1 shares at 141.08.
# Updated Quantity: 1, Updated Avg Cost: 141.08 (Previous Avg Cost: 0.00)
#
# Purchase on 2023-02-27 of 1 shares at 156.22.
# Updated Quantity: 2, Updated Avg Cost: 148.65 (Previous Avg Cost: 141.08)
#
# Purchase on 2023-10-18 of 2 shares at 152.62.
# Updated Quantity: 4, Updated Avg Cost: 150.63 (Previous Avg Cost: 148.65)
#
# Processing GILD:
# Purchase on 2020-04-08 of 2 shares at 74.23.
# Updated Quantity: 2, Updated Avg Cost: 74.23 (Previous Avg Cost: 0.00)
#
# Sell on 2022-11-02 of 2 shares at 78.22.
# Updated Quantity: 0 (Previous Quantity: 2), Avg Cost remains 74.23
#
# Processing ZM:
# Purchase on 2020-04-08 of 1 shares at 124.04.
# Updated Quantity: 1, Updated Avg Cost: 124.04 (Previous Avg Cost: 0.00)
#
# Sell on 2024-12-24 of 1 shares at 85.95.
# Updated Quantity: 0 (Previous Quantity: 1), Avg Cost remains 124.04
#
# Processing DGX:
# Purchase on 2020-04-08 of 2 shares at 175.42.
# Updated Quantity: 2, Updated Avg Cost: 175.42 (Previous Avg Cost: 0.00)
#
# Sell on 2022-11-02 of 2 shares at 130.36.
# Updated Quantity: 0 (Previous Quantity: 2), Avg Cost remains 175.42
#
# Processing WMT:
# Purchase on 2020-04-08 of 1 shares at 121.17.
# Updated Quantity: 1, Updated Avg Cost: 121.17 (Previous Avg Cost: 0.00)
#
# Sell on 2022-10-13 of 1 shares at 130.50.
# Updated Quantity: 0 (Previous Quantity: 1), Avg Cost remains 121.17
#
# Processing DIS:
# Purchase on 2020-04-08 of 2 shares at 99.79.
# Updated Quantity: 2, Updated Avg Cost: 99.79 (Previous Avg Cost: 0.00)
#
# Purchase on 2022-11-14 of 1 shares at 94.68.
# Updated Quantity: 3, Updated Avg Cost: 98.09 (Previous Avg Cost: 99.79)
#
# Purchase on 2022-12-27 of 2 shares at 87.68.
# Updated Quantity: 5, Updated Avg Cost: 93.92 (Previous Avg Cost: 98.09)
#
# Purchase on 2023-03-06 of 2 shares at 102.12.
# Updated Quantity: 7, Updated Avg Cost: 96.27 (Previous Avg Cost: 93.92)
#
# Purchase on 2023-07-10 of 1 shares at 88.38.
# Updated Quantity: 8, Updated Avg Cost: 95.28 (Previous Avg Cost: 96.27)
#
# Purchase on 2023-10-18 of 2 shares at 85.22.
# Updated Quantity: 10, Updated Avg Cost: 93.27 (Previous Avg Cost: 95.28)
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NVTA?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NVTA&crumb=5xFoDikwWRb
# Error fetching data for NVTA: 'NoneType' object has no attribute 'update'
# Error fetching data for ZUO: list index out of range
# Processing YETI:
# Purchase on 2020-04-14 of 5 shares at 25.59.
# Updated Quantity: 5, Updated Avg Cost: 25.59 (Previous Avg Cost: 0.00)
#
# Processing AMD:
# Purchase on 2020-04-14 of 1 shares at 54.69.
# Updated Quantity: 1, Updated Avg Cost: 54.69 (Previous Avg Cost: 0.00)
#
# Purchase on 2023-01-17 of 2 shares at 70.80.
# Updated Quantity: 3, Updated Avg Cost: 65.43 (Previous Avg Cost: 54.69)
#
# Purchase on 2024-11-01 of 5 shares at 142.28.
# Updated Quantity: 8, Updated Avg Cost: 113.46 (Previous Avg Cost: 65.43)
#
# Purchase on 2025-01-13 of 5 shares at 117.79.
# Updated Quantity: 13, Updated Avg Cost: 115.13 (Previous Avg Cost: 113.46)
#
# Purchase on 2025-02-12 of 7 shares at 109.75.
# Updated Quantity: 20, Updated Avg Cost: 113.24 (Previous Avg Cost: 115.13)
#
# Processing UCO:
# Purchase on 2020-03-20 of 0.36 shares at 56.50.
# Updated Quantity: 0.36, Updated Avg Cost: 56.50 (Previous Avg Cost: 0.00)
#
# Purchase on 2020-04-08 of 1.36 shares at 59.00.
# Updated Quantity: 1.7200000000000002, Updated Avg Cost: 58.48 (Previous Avg Cost: 56.50)
#
# Purchase on 2020-04-09 of 0.76 shares at 50.50.
# Updated Quantity: 2.4800000000000004, Updated Avg Cost: 56.03 (Previous Avg Cost: 58.48)
#
# Purchase on 2020-04-15 of 0.52 shares at 41.75.
# Updated Quantity: 3.0000000000000004, Updated Avg Cost: 53.56 (Previous Avg Cost: 56.03)
#
# Purchase on 2020-04-16 of 4 shares at 40.75.
# Updated Quantity: 7.0, Updated Avg Cost: 46.24 (Previous Avg Cost: 53.56)
#
# Stock Split on 2020-04-21: Ratio 0.04.
# Previous Quantity: 7.0, Previous Avg Cost: 46.24
# Updated Quantity: 0.28, Updated Avg Cost: 1155.96
#
# Purchase on 2020-04-27 of 1 shares at 12.63.
# Updated Quantity: 1.28, Updated Avg Cost: 262.73 (Previous Avg Cost: 1155.96)
#
# Error fetching data for UCO: Selling more shares than owned for UCO on 2021-07-15 00:00:00
# Processing DKNG:
# Purchase on 2020-04-24 of 10 shares at 18.78.
# Updated Quantity: 10, Updated Avg Cost: 18.78 (Previous Avg Cost: 0.00)
#
# Processing DAL:
# Purchase on 2020-04-24 of 10 shares at 22.08.
# Updated Quantity: 10, Updated Avg Cost: 22.08 (Previous Avg Cost: 0.00)
#
# Purchase on 2020-05-15 of 2 shares at 19.31.
# Updated Quantity: 12, Updated Avg Cost: 21.62 (Previous Avg Cost: 22.08)
#
# Purchase on 2020-09-09 of 1 shares at 31.82.
# Updated Quantity: 13, Updated Avg Cost: 22.40 (Previous Avg Cost: 21.62)
#
# Sell on 2022-10-14 of 13 shares at 31.33.
# Updated Quantity: 0 (Previous Quantity: 13), Avg Cost remains 22.40
#
# Processing USB:
# Purchase on 2020-05-28 of 10 shares at 36.83.
# Updated Quantity: 10, Updated Avg Cost: 36.83 (Previous Avg Cost: 0.00)
#
# Sell on 2022-10-13 of 10 shares at 40.92.
# Updated Quantity: 0 (Previous Quantity: 10), Avg Cost remains 36.83
#
# Processing C:
# Purchase on 2020-05-28 of 7 shares at 50.56.
# Updated Quantity: 7, Updated Avg Cost: 50.56 (Previous Avg Cost: 0.00)
#
# Purchase on 2020-11-25 of 1 shares at 56.51.
# Updated Quantity: 8, Updated Avg Cost: 51.30 (Previous Avg Cost: 50.56)
#
# Sell on 2022-10-13 of 8 shares at 42.75.
# Updated Quantity: 0 (Previous Quantity: 8), Avg Cost remains 51.30
#
# Processing BAC:
# Purchase on 2020-05-28 of 11 shares at 25.26.
# Updated Quantity: 11, Updated Avg Cost: 25.26 (Previous Avg Cost: 0.00)
#
# Sell on 2022-10-13 of 11 shares at 31.36.
# Updated Quantity: 0 (Previous Quantity: 11), Avg Cost remains 25.26
#
# Processing ALGT:
# Purchase on 2020-09-09 of 2 shares at 132.43.
# Updated Quantity: 2, Updated Avg Cost: 132.43 (Previous Avg Cost: 0.00)
#
# Sell on 2022-10-14 of 2 shares at 67.10.
# Updated Quantity: 0 (Previous Quantity: 2), Avg Cost remains 132.43
#
# Processing JBLU:
# Purchase on 2020-09-09 of 20 shares at 12.21.
# Updated Quantity: 20, Updated Avg Cost: 12.21 (Previous Avg Cost: 0.00)
#
# Sell on 2022-10-14 of 20 shares at 6.71.
# Updated Quantity: 0 (Previous Quantity: 20), Avg Cost remains 12.21
#
# Processing LUV:
# Purchase on 2020-09-09 of 12 shares at 39.48.
# Updated Quantity: 12, Updated Avg Cost: 39.48 (Previous Avg Cost: 0.00)
#
# Sell on 2022-10-14 of 12 shares at 32.73.
# Updated Quantity: 0 (Previous Quantity: 12), Avg Cost remains 39.48
#
# Processing FSLY:
# Purchase on 2020-10-28 of 13 shares at 71.40.
# Updated Quantity: 13, Updated Avg Cost: 71.40 (Previous Avg Cost: 0.00)
#
# Purchase on 2020-11-02 of 1 shares at 64.90.
# Updated Quantity: 14, Updated Avg Cost: 70.94 (Previous Avg Cost: 71.40)
#
# Processing OPTT:
# Purchase on 2021-01-29 of 9 shares at 3.17.
# Updated Quantity: 9, Updated Avg Cost: 3.17 (Previous Avg Cost: 0.00)
#
# Sell on 2021-01-29 of 9 shares at 0.71.
# Updated Quantity: 0 (Previous Quantity: 9), Avg Cost remains 3.17
#
# Processing MARA:
# Purchase on 2021-01-04 of 6 shares at 10.70.
# Updated Quantity: 6, Updated Avg Cost: 10.70 (Previous Avg Cost: 0.00)
#
# Purchase on 2021-01-12 of 1 shares at 25.95.
# Updated Quantity: 7, Updated Avg Cost: 12.88 (Previous Avg Cost: 10.70)
#
# Purchase on 2021-01-15 of 3 shares at 23.13.
# Updated Quantity: 10, Updated Avg Cost: 15.95 (Previous Avg Cost: 12.88)
#
# Sell on 2023-10-09 of 10 shares at 7.96.
# Updated Quantity: 0 (Previous Quantity: 10), Avg Cost remains 15.95
#
# Processing BB:
# Purchase on 2021-01-27 of 45 shares at 20.84.
# Updated Quantity: 45, Updated Avg Cost: 20.84 (Previous Avg Cost: 0.00)
#
# Processing NOK:
# Purchase on 2021-01-27 of 10 shares at 6.59.
# Updated Quantity: 10, Updated Avg Cost: 6.59 (Previous Avg Cost: 0.00)
#
# Sell on 2022-11-02 of 10 shares at 4.40.
# Updated Quantity: 0 (Previous Quantity: 10), Avg Cost remains 6.59
#
# Processing PLUG:
# Purchase on 2021-03-17 of 25 shares at 37.34.
# Updated Quantity: 25, Updated Avg Cost: 37.34 (Previous Avg Cost: 0.00)
#
# Purchase on 2021-03-25 of 3 shares at 32.31.
# Updated Quantity: 28, Updated Avg Cost: 36.80 (Previous Avg Cost: 37.34)
#
# Purchase on 2021-04-12 of 33 shares at 29.05.
# Updated Quantity: 61, Updated Avg Cost: 32.61 (Previous Avg Cost: 36.80)
#
# Purchase on 2023-10-11 of 39 shares at 7.52.
# Updated Quantity: 100, Updated Avg Cost: 22.82 (Previous Avg Cost: 32.61)
#
# Purchase on 2024-10-02 of 50 shares at 2.17.
# Updated Quantity: 150, Updated Avg Cost: 15.94 (Previous Avg Cost: 22.82)
#
# Processing TXMD:
# Purchase on 2021-03-30 of 35 shares at 1.33.
# Updated Quantity: 35, Updated Avg Cost: 1.33 (Previous Avg Cost: 0.00)
#
# Stock Split on 2022-05-09: Ratio 0.02.
# Previous Quantity: 35, Previous Avg Cost: 1.33
# Updated Quantity: 0.7000000000000001, Updated Avg Cost: 66.50
#
# Error fetching data for TXMD: Selling more shares than owned for TXMD on 2022-08-25 00:00:00
# Processing HOOD:
# Purchase on 2021-07-29 of 17 shares at 35.00.
# Updated Quantity: 17, Updated Avg Cost: 35.00 (Previous Avg Cost: 0.00)
#
# Processing OTLY:
# Purchase on 2021-08-18 of 10 shares at 15.25.
# Updated Quantity: 10, Updated Avg Cost: 15.25 (Previous Avg Cost: 0.00)
#
# Purchase on 2021-12-18 of 2 shares at 7.78.
# Updated Quantity: 12, Updated Avg Cost: 14.01 (Previous Avg Cost: 15.25)
#
# Purchase on 2022-03-24 of 2 shares at 5.20.
# Updated Quantity: 14, Updated Avg Cost: 12.75 (Previous Avg Cost: 14.01)
#
# Purchase on 2022-11-14 of 4 shares at 2.05.
# Updated Quantity: 18, Updated Avg Cost: 10.37 (Previous Avg Cost: 12.75)
#
# Purchase on 2023-01-13 of 18 shares at 2.52.
# Updated Quantity: 36, Updated Avg Cost: 6.44 (Previous Avg Cost: 10.37)
#
# Purchase on 2023-03-06 of 20 shares at 2.31.
# Updated Quantity: 56, Updated Avg Cost: 4.97 (Previous Avg Cost: 6.44)
#
# Purchase on 2023-05-26 of 44 shares at 1.72.
# Updated Quantity: 100, Updated Avg Cost: 3.54 (Previous Avg Cost: 4.97)
#
# Stock Split on 2025-02-18: Ratio 0.05.
# Previous Quantity: 100, Previous Avg Cost: 3.54
# Updated Quantity: 5.0, Updated Avg Cost: 70.78
#
# Processing CHGG:
# Purchase on 2021-11-05 of 29 shares at 31.79.
# Updated Quantity: 29, Updated Avg Cost: 31.79 (Previous Avg Cost: 0.00)
#
# Purchase on 2021-11-19 of 1 shares at 26.53.
# Updated Quantity: 30, Updated Avg Cost: 31.61 (Previous Avg Cost: 31.79)
#
# Sell on 2023-05-02 of 30 shares at 9.11.
# Updated Quantity: 0 (Previous Quantity: 30), Avg Cost remains 31.61
#
# Processing COST:
# Purchase on 2022-03-15 of 1 shares at 542.32.
# Updated Quantity: 1, Updated Avg Cost: 542.32 (Previous Avg Cost: 0.00)
#
# Purchase on 2022-08-25 of 1 shares at 548.06.
# Updated Quantity: 2, Updated Avg Cost: 545.19 (Previous Avg Cost: 542.32)
#
# Processing SNOW:
# Purchase on 2022-03-15 of 2 shares at 171.83.
# Updated Quantity: 2, Updated Avg Cost: 171.83 (Previous Avg Cost: 0.00)
#
# Purchase on 2022-07-11 of 1 shares at 155.60.
# Updated Quantity: 3, Updated Avg Cost: 166.42 (Previous Avg Cost: 171.83)
#
# Purchase on 2022-09-14 of 2 shares at 187.71.
# Updated Quantity: 5, Updated Avg Cost: 174.94 (Previous Avg Cost: 166.42)
#
# Purchase on 2023-10-20 of 3 shares at 148.16.
# Updated Quantity: 8, Updated Avg Cost: 164.90 (Previous Avg Cost: 174.94)
#
# Purchase on 2024-02-28 of 2 shares at 176.00.
# Updated Quantity: 10, Updated Avg Cost: 167.12 (Previous Avg Cost: 164.90)
#
# Purchase on 2024-08-02 of 3 shares at 119.89.
# Updated Quantity: 13, Updated Avg Cost: 156.22 (Previous Avg Cost: 167.12)
#
# Processing DUOL:
# Purchase on 2022-03-21 of 5 shares at 92.00.
# Updated Quantity: 5, Updated Avg Cost: 92.00 (Previous Avg Cost: 0.00)
#
# Processing SPOT:
# Purchase on 2022-03-21 of 2 shares at 145.00.
# Updated Quantity: 2, Updated Avg Cost: 145.00 (Previous Avg Cost: 0.00)
#
# Purchase on 2022-04-29 of 2 shares at 103.00.
# Updated Quantity: 4, Updated Avg Cost: 124.00 (Previous Avg Cost: 145.00)
#
# Processing CSV:
# Purchase on 2022-03-21 of 2 shares at 108.19.
# Updated Quantity: 2, Updated Avg Cost: 108.19 (Previous Avg Cost: 0.00)
#
# Processing BE:
# Purchase on 2022-03-21 of 2 shares at 24.00.
# Updated Quantity: 2, Updated Avg Cost: 24.00 (Previous Avg Cost: 0.00)
#
# Purchase on 2022-04-29 of 10 shares at 19.40.
# Updated Quantity: 12, Updated Avg Cost: 20.17 (Previous Avg Cost: 24.00)
#
# Purchase on 2022-05-06 of 6 shares at 15.30.
# Updated Quantity: 18, Updated Avg Cost: 18.54 (Previous Avg Cost: 20.17)
#
# Purchase on 2022-05-09 of 5 shares at 13.50.
# Updated Quantity: 23, Updated Avg Cost: 17.45 (Previous Avg Cost: 18.54)
#
# Purchase on 2023-06-05 of 4 shares at 14.44.
# Updated Quantity: 27, Updated Avg Cost: 17.00 (Previous Avg Cost: 17.45)
#
# Purchase on 2023-06-26 of 6 shares at 15.74.
# Updated Quantity: 33, Updated Avg Cost: 16.77 (Previous Avg Cost: 17.00)
#
# Purchase on 2023-10-23 of 17 shares at 11.19.
# Updated Quantity: 50, Updated Avg Cost: 14.87 (Previous Avg Cost: 16.77)
#
# Purchase on 2023-12-12 of 20 shares at 12.80.
# Updated Quantity: 70, Updated Avg Cost: 14.28 (Previous Avg Cost: 14.87)
#
# Purchase on 2024-01-16 of 15 shares at 12.25.
# Updated Quantity: 85, Updated Avg Cost: 13.92 (Previous Avg Cost: 14.28)
#
# Purchase on 2024-02-21 of 15 shares at 8.82.
# Updated Quantity: 100, Updated Avg Cost: 13.16 (Previous Avg Cost: 13.92)
#
# Processing ABNB:
# Purchase on 2022-03-21 of 3 shares at 165.35.
# Updated Quantity: 3, Updated Avg Cost: 165.35 (Previous Avg Cost: 0.00)
#
# Purchase on 2022-05-09 of 2 shares at 121.05.
# Updated Quantity: 5, Updated Avg Cost: 147.63 (Previous Avg Cost: 165.35)
#
# Processing AAPL:
# Purchase on 2022-03-21 of 3 shares at 166.47.
# Updated Quantity: 3, Updated Avg Cost: 166.47 (Previous Avg Cost: 0.00)
#
# Processing SEDG:
# Purchase on 2022-05-06 of 2 shares at 252.37.
# Updated Quantity: 2, Updated Avg Cost: 252.37 (Previous Avg Cost: 0.00)
#
# Purchase on 2022-10-18 of 1 shares at 121.48.
# Updated Quantity: 3, Updated Avg Cost: 208.74 (Previous Avg Cost: 252.37)
#
# Purchase on 2022-10-20 of 5 shares at 83.96.
# Updated Quantity: 8, Updated Avg Cost: 130.75 (Previous Avg Cost: 208.74)
#
# Purchase on 2023-08-15 of 1 shares at 171.50.
# Updated Quantity: 9, Updated Avg Cost: 135.28 (Previous Avg Cost: 130.75)
#
# Purchase on 2023-09-18 of 1 shares at 136.68.
# Updated Quantity: 10, Updated Avg Cost: 135.42 (Previous Avg Cost: 135.28)
#
# Processing ADYEY:
# Purchase on 2022-05-06 of 9 shares at 15.08.
# Updated Quantity: 9, Updated Avg Cost: 15.08 (Previous Avg Cost: 0.00)
#
# Sell on 2022-08-29 of 9 shares at 15.84.
# Updated Quantity: 0 (Previous Quantity: 9), Avg Cost remains 15.08
#
# Processing DXCM:
# Purchase on 2022-05-06 of 1 shares at 351.41.
# Updated Quantity: 1, Updated Avg Cost: 351.41 (Previous Avg Cost: 0.00)
#
# Stock Split on 2022-06-13: Ratio 4.0.
# Previous Quantity: 1, Previous Avg Cost: 351.41
# Updated Quantity: 4.0, Updated Avg Cost: 87.85
#
# Sell on 2022-09-09 of 4 shares at 92.69.
# Updated Quantity: 0.0 (Previous Quantity: 4.0), Avg Cost remains 87.85
# $ROVR: possibly delisted; no timezone found
# Processing ROVR:
# Purchase on 2022-06-21 of 24 shares at 4.29.
# Updated Quantity: 24, Updated Avg Cost: 4.29 (Previous Avg Cost: 0.00)
#
# Purchase on 2022-09-23 of 26 shares at 3.24.
# Updated Quantity: 50, Updated Avg Cost: 3.74 (Previous Avg Cost: 4.29)
#
# Purchase on 2022-10-14 of 20 shares at 3.80.
# Updated Quantity: 70, Updated Avg Cost: 3.76 (Previous Avg Cost: 3.74)
#
# Sell on 2024-02-28 of 70 shares at 11.00.
# Updated Quantity: 0 (Previous Quantity: 70), Avg Cost remains 3.76
#
# Processing MELI:
# Purchase on 2022-08-03 of 0.14 shares at 993.00.
# Updated Quantity: 0.14, Updated Avg Cost: 993.00 (Previous Avg Cost: 0.00)
#
# Purchase on 2022-08-25 of 0.35 shares at 913.54.
# Updated Quantity: 0.49, Updated Avg Cost: 936.24 (Previous Avg Cost: 993.00)
#
# Purchase on 2022-08-25 of 0.01 shares at 914.00.
# Updated Quantity: 0.5, Updated Avg Cost: 935.80 (Previous Avg Cost: 936.24)
#
# Purchase on 2022-10-14 of 0.5 shares at 800.00.
# Updated Quantity: 1.0, Updated Avg Cost: 867.90 (Previous Avg Cost: 935.80)
#
# Processing O:
# Purchase on 2022-08-19 of 1 shares at 73.07.
# Updated Quantity: 1, Updated Avg Cost: 73.07 (Previous Avg Cost: 0.00)
#
# Purchase on 2022-08-25 of 1 shares at 71.26.
# Updated Quantity: 2, Updated Avg Cost: 72.16 (Previous Avg Cost: 73.07)
#
# Purchase on 2022-08-25 of 3 shares at 69.66.
# Updated Quantity: 5, Updated Avg Cost: 70.66 (Previous Avg Cost: 72.16)
#
# Purchase on 2022-09-12 of 2 shares at 67.09.
# Updated Quantity: 7, Updated Avg Cost: 69.64 (Previous Avg Cost: 70.66)
#
# Purchase on 2022-09-14 of 1 shares at 66.05.
# Updated Quantity: 8, Updated Avg Cost: 69.19 (Previous Avg Cost: 69.64)
#
# Purchase on 2022-09-29 of 4 shares at 57.78.
# Updated Quantity: 12, Updated Avg Cost: 65.39 (Previous Avg Cost: 69.19)
#
# Purchase on 2023-06-12 of 1 shares at 60.73.
# Updated Quantity: 13, Updated Avg Cost: 65.03 (Previous Avg Cost: 65.39)
#
# Purchase on 2023-09-28 of 4 shares at 49.80.
# Updated Quantity: 17, Updated Avg Cost: 61.45 (Previous Avg Cost: 65.03)
#
# Purchase on 2023-10-30 of 10 shares at 45.90.
# Updated Quantity: 27, Updated Avg Cost: 55.69 (Previous Avg Cost: 61.45)
#
# Processing AFCG:
# Purchase on 2022-09-06 of 5 shares at 16.78.
# Updated Quantity: 5, Updated Avg Cost: 16.78 (Previous Avg Cost: 0.00)
#
# Purchase on 2022-09-12 of 4 shares at 17.54.
# Updated Quantity: 9, Updated Avg Cost: 17.12 (Previous Avg Cost: 16.78)
#
# Purchase on 2022-09-14 of 3 shares at 17.33.
# Updated Quantity: 12, Updated Avg Cost: 17.17 (Previous Avg Cost: 17.12)
#
# Purchase on 2022-10-07 of 3 shares at 16.04.
# Updated Quantity: 15, Updated Avg Cost: 16.94 (Previous Avg Cost: 17.17)
#
# Purchase on 2022-10-14 of 3 shares at 16.21.
# Updated Quantity: 18, Updated Avg Cost: 16.82 (Previous Avg Cost: 16.94)
#
# Purchase on 2022-11-14 of 3 shares at 15.87.
# Updated Quantity: 21, Updated Avg Cost: 16.69 (Previous Avg Cost: 16.82)
#
# Purchase on 2023-04-04 of 9 shares at 11.89.
# Updated Quantity: 30, Updated Avg Cost: 15.25 (Previous Avg Cost: 16.69)
#
# Stock Split on 2024-07-10: Ratio 1.461.
# Previous Quantity: 30, Previous Avg Cost: 15.25
# Updated Quantity: 43.830000000000005, Updated Avg Cost: 10.44
#
# Processing MSFT:
# Purchase on 2016-09-21 of 5 shares at 57.17.
# Updated Quantity: 5, Updated Avg Cost: 57.17 (Previous Avg Cost: 0.00)
#
# Sell on 2017-08-23 of 5 shares at 73.06.
# Updated Quantity: 0 (Previous Quantity: 5), Avg Cost remains 57.17
#
# Purchase on 2022-09-12 of 2 shares at 266.06.
# Updated Quantity: 2, Updated Avg Cost: 266.06 (Previous Avg Cost: 57.17)
#
# Purchase on 2022-10-14 of 1 shares at 231.28.
# Updated Quantity: 3, Updated Avg Cost: 254.47 (Previous Avg Cost: 266.06)
#
# Processing COF:
# Purchase on 2017-01-17 of 1 shares at 87.26.
# Updated Quantity: 1, Updated Avg Cost: 87.26 (Previous Avg Cost: 0.00)
#
# Sell on 2017-08-23 of 1 shares at 81.54.
# Updated Quantity: 0 (Previous Quantity: 1), Avg Cost remains 87.26
#
# Purchase on 2022-09-13 of 5 shares at 101.62.
# Updated Quantity: 5, Updated Avg Cost: 101.62 (Previous Avg Cost: 87.26)
#
# Purchase on 2022-10-18 of 1 shares at 96.52.
# Updated Quantity: 6, Updated Avg Cost: 100.77 (Previous Avg Cost: 101.62)
#
# Purchase on 2022-10-20 of 5 shares at 91.11.
# Updated Quantity: 11, Updated Avg Cost: 96.38 (Previous Avg Cost: 100.77)
#
# Purchase on 2023-03-13 of 1 shares at 93.90.
# Updated Quantity: 12, Updated Avg Cost: 96.17 (Previous Avg Cost: 96.38)
#
# Processing TREX:
# Purchase on 2022-09-20 of 2 shares at 46.53.
# Updated Quantity: 2, Updated Avg Cost: 46.53 (Previous Avg Cost: 0.00)
#
# Purchase on 2022-11-28 of 3 shares at 43.85.
# Updated Quantity: 5, Updated Avg Cost: 44.92 (Previous Avg Cost: 46.53)
#
# Sell on 2024-06-24 of 4 shares at 79.21.
# Updated Quantity: 1 (Previous Quantity: 5), Avg Cost remains 44.92
#
# Error fetching data for TREX: Selling more shares than owned for TREX on 2024-10-07 00:00:00
# Processing WM:
# Purchase on 2022-10-07 of 1 shares at 157.32.
# Updated Quantity: 1, Updated Avg Cost: 157.32 (Previous Avg Cost: 0.00)
#
# Purchase on 2023-01-23 of 1 shares at 152.49.
# Updated Quantity: 2, Updated Avg Cost: 154.91 (Previous Avg Cost: 157.32)
#
# Purchase on 2023-08-07 of 1 shares at 161.29.
# Updated Quantity: 3, Updated Avg Cost: 157.03 (Previous Avg Cost: 154.91)
#
# Processing GOOG:
# Purchase on 2022-10-10 of 1 shares at 98.40.
# Updated Quantity: 1, Updated Avg Cost: 98.40 (Previous Avg Cost: 0.00)
#
# Purchase on 2022-10-14 of 2 shares at 98.02.
# Updated Quantity: 3, Updated Avg Cost: 98.15 (Previous Avg Cost: 98.40)
#
# Purchase on 2022-10-27 of 1 shares at 93.08.
# Updated Quantity: 4, Updated Avg Cost: 96.88 (Previous Avg Cost: 98.15)
#
# Processing TXN:
# Purchase on 2022-10-14 of 3 shares at 151.13.
# Updated Quantity: 3, Updated Avg Cost: 151.13 (Previous Avg Cost: 0.00)
#
# Processing ABBV:
# Purchase on 2022-10-14 of 5 shares at 143.24.
# Updated Quantity: 5, Updated Avg Cost: 143.24 (Previous Avg Cost: 0.00)
#
# Processing VZ:
# Purchase on 2022-10-21 of 3 shares at 35.04.
# Updated Quantity: 3, Updated Avg Cost: 35.04 (Previous Avg Cost: 0.00)
#
# Purchase on 2022-10-31 of 3 shares at 37.26.
# Updated Quantity: 6, Updated Avg Cost: 36.15 (Previous Avg Cost: 35.04)
#
# Purchase on 2023-03-20 of 3 shares at 37.41.
# Updated Quantity: 9, Updated Avg Cost: 36.57 (Previous Avg Cost: 36.15)
#
# Purchase on 2023-04-10 of 8 shares at 39.17.
# Updated Quantity: 17, Updated Avg Cost: 37.79 (Previous Avg Cost: 36.57)
#
# Purchase on 2023-07-17 of 5 shares at 31.38.
# Updated Quantity: 22, Updated Avg Cost: 36.34 (Previous Avg Cost: 37.79)
#
# Purchase on 2023-10-12 of 3 shares at 30.81.
# Updated Quantity: 25, Updated Avg Cost: 35.67 (Previous Avg Cost: 36.34)
#
# Purchase on 2025-01-23 of 10 shares at 39.22.
# Updated Quantity: 35, Updated Avg Cost: 36.69 (Previous Avg Cost: 35.67)
#
# Processing TTD:
# Purchase on 2022-12-05 of 2 shares at 54.42.
# Updated Quantity: 2, Updated Avg Cost: 54.42 (Previous Avg Cost: 0.00)
#
# Purchase on 2022-12-15 of 2 shares at 47.48.
# Updated Quantity: 4, Updated Avg Cost: 50.95 (Previous Avg Cost: 54.42)
#
# Purchase on 2023-11-20 of 4 shares at 67.79.
# Updated Quantity: 8, Updated Avg Cost: 59.37 (Previous Avg Cost: 50.95)
#
# Purchase on 2025-02-13 of 10 shares at 81.98.
# Updated Quantity: 18, Updated Avg Cost: 71.93 (Previous Avg Cost: 59.37)
#
# Processing CRWD:
# Purchase on 2022-01-04 of 4 shares at 103.52.
# Updated Quantity: 4, Updated Avg Cost: 103.52 (Previous Avg Cost: 0.00)
#
# Processing LOW:
# Purchase on 2023-01-30 of 1 shares at 203.38.
# Updated Quantity: 1, Updated Avg Cost: 203.38 (Previous Avg Cost: 0.00)
#
# Purchase on 2023-01-30 of 4 shares at 190.81.
# Updated Quantity: 5, Updated Avg Cost: 193.32 (Previous Avg Cost: 203.38)
#
# Processing BEPC:
# Purchase on 2023-10-06 of 3 shares at 22.14.
# Updated Quantity: 3, Updated Avg Cost: 22.14 (Previous Avg Cost: 0.00)
#
# Purchase on 2023-10-11 of 27 shares at 23.80.
# Updated Quantity: 30, Updated Avg Cost: 23.63 (Previous Avg Cost: 22.14)
#
# Purchase on 2024-03-25 of 10 shares at 24.17.
# Updated Quantity: 40, Updated Avg Cost: 23.77 (Previous Avg Cost: 23.63)
#
# Purchase on 2025-01-23 of 20 shares at 24.71.
# Updated Quantity: 60, Updated Avg Cost: 24.08 (Previous Avg Cost: 23.77)
#
# Processing PLD:
# Purchase on 2023-11-21 of 3 shares at 110.21.
# Updated Quantity: 3, Updated Avg Cost: 110.21 (Previous Avg Cost: 0.00)
#
# Purchase on 2024-04-02 of 2 shares at 125.06.
# Updated Quantity: 5, Updated Avg Cost: 116.15 (Previous Avg Cost: 110.21)
#
# Purchase on 2024-04-22 of 2 shares at 103.23.
# Updated Quantity: 7, Updated Avg Cost: 112.46 (Previous Avg Cost: 116.15)
#
# Processing MRNA:
# Purchase on 2024-04-12 of 3 shares at 105.53.
# Updated Quantity: 3, Updated Avg Cost: 105.53 (Previous Avg Cost: 0.00)
#
# Purchase on 2024-09-02 of 4 shares at 77.55.
# Updated Quantity: 7, Updated Avg Cost: 89.54 (Previous Avg Cost: 105.53)
#
# Purchase on 2024-10-28 of 7 shares at 53.65.
# Updated Quantity: 14, Updated Avg Cost: 71.60 (Previous Avg Cost: 89.54)
#
# Purchase on 2024-10-28 of 6 shares at 42.35.
# Updated Quantity: 20, Updated Avg Cost: 62.82 (Previous Avg Cost: 71.60)
#
# Purchase on 2025-01-14 of 10 shares at 35.20.
# Updated Quantity: 30, Updated Avg Cost: 53.61 (Previous Avg Cost: 62.82)
#
# Purchase on 2025-02-13 of 10 shares at 31.58.
# Updated Quantity: 40, Updated Avg Cost: 48.11 (Previous Avg Cost: 53.61)
#
# Processing ASML:
# Purchase on 2024-12-02 of 1 shares at 683.90.
# Updated Quantity: 1, Updated Avg Cost: 683.90 (Previous Avg Cost: 0.00)
#
# Purchase on 2025-03-27 of 1 shares at 692.54.
# Updated Quantity: 2, Updated Avg Cost: 688.22 (Previous Avg Cost: 683.90)
#
# Processing VICI:
# Purchase on 2025-01-23 of 20 shares at 29.18.
# Updated Quantity: 20, Updated Avg Cost: 29.18 (Previous Avg Cost: 0.00)
#
# Processing CMG:
# Purchase on 2025-02-14 of 10 shares at 57.24.
# Updated Quantity: 10, Updated Avg Cost: 57.24 (Previous Avg Cost: 0.00)
#
# Processing BLV:
# Purchase on 2016-08-05 of 3 shares at 100.87.
# Updated Quantity: 3, Updated Avg Cost: 100.87 (Previous Avg Cost: 0.00)
#
# Purchase on 2018-02-02 of 3 shares at 92.90.
# Updated Quantity: 6, Updated Avg Cost: 96.89 (Previous Avg Cost: 100.87)
#
# Purchase on 2021-03-09 of 6 shares at 98.47.
# Updated Quantity: 12, Updated Avg Cost: 97.68 (Previous Avg Cost: 96.89)
#
# Purchase on 2023-03-06 of 12 shares at 74.04.
# Updated Quantity: 24, Updated Avg Cost: 85.86 (Previous Avg Cost: 97.68)
#
# Processing SCHD:
# Purchase on 2019-01-29 of 0.61349 shares at 48.90.
# Updated Quantity: 0.61349, Updated Avg Cost: 48.90 (Previous Avg Cost: 0.00)
#
# Purchase on 2019-06-18 of 0.47046 shares at 53.14.
# Updated Quantity: 1.08395, Updated Avg Cost: 50.74 (Previous Avg Cost: 48.90)
#
# Purchase on 2021-03-09 of 0.07048 shares at 70.95.
# Updated Quantity: 1.15443, Updated Avg Cost: 51.97 (Previous Avg Cost: 50.74)
#
# Purchase on 2021-03-16 of 0.0694 shares at 72.05.
# Updated Quantity: 1.22383, Updated Avg Cost: 53.11 (Previous Avg Cost: 51.97)
#
# Purchase on 2021-03-23 of 0.07013 shares at 71.30.
# Updated Quantity: 1.29396, Updated Avg Cost: 54.10 (Previous Avg Cost: 53.11)
#
# Purchase on 2021-03-30 of 0.06838 shares at 73.12.
# Updated Quantity: 1.36234, Updated Avg Cost: 55.05 (Previous Avg Cost: 54.10)
#
# Stock Split on 2024-10-11: Ratio 3.0.
# Previous Quantity: 1.36234, Previous Avg Cost: 55.05
# Updated Quantity: 4.087020000000001, Updated Avg Cost: 18.35
#
# Processing VB:
# Purchase on 2023-01-04 of 4 shares at 185.98.
# Updated Quantity: 4, Updated Avg Cost: 185.98 (Previous Avg Cost: 0.00)
#
# Purchase on 2023-03-06 of 3 shares at 201.37.
# Updated Quantity: 7, Updated Avg Cost: 192.58 (Previous Avg Cost: 185.98)
#
# Updated Quantity: 30, Updated Avg Cost: 84.93 (Previous Avg Cost: 85.44)
#
# Purchase on 2020-08-07 of 6 shares at 80.93.
# Updated Quantity: 36, Updated Avg Cost: 84.26 (Previous Avg Cost: 84.93)
#
# Purchase on 2021-01-04 of 8 shares at 85.20.
# Updated Quantity: 44, Updated Avg Cost: 84.43 (Previous Avg Cost: 84.26)
#
# Purchase on 2021-12-28 of 4 shares at 113.93.
# Updated Quantity: 48, Updated Avg Cost: 86.89 (Previous Avg Cost: 84.43)
#
# Purchase on 2022-07-05 of 10 shares at 91.81.
# Updated Quantity: 58, Updated Avg Cost: 87.74 (Previous Avg Cost: 86.89)
#
# Purchase on 2023-07-06 of 8 shares at 83.66.
# Updated Quantity: 66, Updated Avg Cost: 87.25 (Previous Avg Cost: 87.74)
#
# Processing VOE:
# Purchase on 2016-08-04 of 8 shares at 93.07.
# Updated Quantity: 8, Updated Avg Cost: 93.07 (Previous Avg Cost: 0.00)
#
# Purchase on 2018-09-04 of 8 shares at 115.06.
# Updated Quantity: 16, Updated Avg Cost: 104.06 (Previous Avg Cost: 93.07)
#
# Purchase on 2020-07-06 of 3 shares at 97.22.
# Updated Quantity: 19, Updated Avg Cost: 102.98 (Previous Avg Cost: 104.06)
#
# Purchase on 2020-08-07 of 4 shares at 101.65.
# Updated Quantity: 23, Updated Avg Cost: 102.75 (Previous Avg Cost: 102.98)
#
# Purchase on 2020-11-09 of 6 shares at 113.48.
# Updated Quantity: 29, Updated Avg Cost: 104.97 (Previous Avg Cost: 102.75)
#
# Processing VOO:
# Purchase on 2016-07-07 of 3 shares at 195.24.
# Updated Quantity: 3, Updated Avg Cost: 195.24 (Previous Avg Cost: 0.00)
#
# Purchase on 2017-02-07 of 5 shares at 212.24.
# Updated Quantity: 8, Updated Avg Cost: 205.87 (Previous Avg Cost: 195.24)
#
# Purchase on 2020-05-01 of 3 shares at 262.14.
# Updated Quantity: 11, Updated Avg Cost: 221.21 (Previous Avg Cost: 205.87)
#
# Purchase on 2020-10-06 of 3 shares at 311.98.
# Updated Quantity: 14, Updated Avg Cost: 240.66 (Previous Avg Cost: 221.21)
#
# Purchase on 2021-04-09 of 2 shares at 375.49.
# Updated Quantity: 16, Updated Avg Cost: 257.52 (Previous Avg Cost: 240.66)
#
# Purchase on 2021-12-06 of 1 shares at 419.36.
# Updated Quantity: 17, Updated Avg Cost: 267.04 (Previous Avg Cost: 257.52)
#
# Purchase on 2021-12-28 of 3 shares at 439.28.
# Updated Quantity: 20, Updated Avg Cost: 292.87 (Previous Avg Cost: 267.04)
#
# Purchase on 2022-08-11 of 2 shares at 387.00.
# Updated Quantity: 22, Updated Avg Cost: 301.43 (Previous Avg Cost: 292.87)
#
# Processing VUG:
# Purchase on 2023-10-04 of 3 shares at 272.02.
# Updated Quantity: 3, Updated Avg Cost: 272.02 (Previous Avg Cost: 0.00)
#
# Purchase on 2024-01-02 of 4 shares at 307.92.
# Updated Quantity: 7, Updated Avg Cost: 292.53 (Previous Avg Cost: 272.02)
#
# Purchase on 2024-02-06 of 4 shares at 328.58.
# Updated Quantity: 11, Updated Avg Cost: 305.64 (Previous Avg Cost: 292.53)
#
# Purchase on 2024-03-04 of 2 shares at 343.04.
# Updated Quantity: 13, Updated Avg Cost: 311.40 (Previous Avg Cost: 305.64)
#
# Purchase on 2024-06-11 of 2 shares at 362.70.
# Updated Quantity: 15, Updated Avg Cost: 318.24 (Previous Avg Cost: 311.40)
#
# Purchase on 2024-08-05 of 1 shares at 331.13.
# Updated Quantity: 16, Updated Avg Cost: 319.04 (Previous Avg Cost: 318.24)
#
# Purchase on 2024-09-05 of 2 shares at 363.06.
# Updated Quantity: 18, Updated Avg Cost: 323.93 (Previous Avg Cost: 319.04)
#
# Processing VWO:
# Purchase on 2016-08-04 of 17 shares at 37.55.
# Updated Quantity: 17, Updated Avg Cost: 37.55 (Previous Avg Cost: 0.00)
#
# Purchase on 2021-08-05 of 20 shares at 51.84.
# Updated Quantity: 37, Updated Avg Cost: 45.27 (Previous Avg Cost: 37.55)
#
# Purchase on 2022-04-04 of 20 shares at 47.60.
# Updated Quantity: 57, Updated Avg Cost: 46.09 (Previous Avg Cost: 45.27)
#
# Purchase on 2024-04-05 of 18 shares at 39.64.
# Updated Quantity: 75, Updated Avg Cost: 44.54 (Previous Avg Cost: 46.09)
# /var/folders/3l/flqcxq8n6xd5d268qr1vn1_00000gn/T/ipykernel_22963/4276215736.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_stocks['Price'] = round(filtered_stocks['Price'],2)
# /var/folders/3l/flqcxq8n6xd5d268qr1vn1_00000gn/T/ipykernel_22963/4276215736.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_stocks['Quantity'] = round(filtered_stocks['Quantity'],2)
# /var/folders/3l/flqcxq8n6xd5d268qr1vn1_00000gn/T/ipykernel_22963/4276215736.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_stocks['Avg_Cost'] = round(filtered_stocks['Avg_Cost'],2)
# /var/folders/3l/flqcxq8n6xd5d268qr1vn1_00000gn/T/ipykernel_22963/4276215736.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_stocks['Market_Value'] = round(filtered_stocks['Market_Value'],2)
# /var/folders/3l/flqcxq8n6xd5d268qr1vn1_00000gn/T/ipykernel_22963/4276215736.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_stocks['Percent_Change'] = round(filtered_stocks['Percent_Change'],2)
# /var/folders/3l/flqcxq8n6xd5d268qr1vn1_00000gn/T/ipykernel_22963/4276215736.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_stocks['Equity_Change'] = round(filtered_stocks['Equity_Change'],2)
# /var/folders/3l/flqcxq8n6xd5d268qr1vn1_00000gn/T/ipykernel_22963/4276215736.py:149: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_stocks['52_Week_High'] = round(filtered_stocks['52_Week_High'],2)
# /var/folders/3l/flqcxq8n6xd5d268qr1vn1_00000gn/T/ipykernel_22963/4276215736.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_stocks['52_Week_Low'] = round(filtered_stocks['52_Week_Low'],2)
# Processing MRNA:
# Purchase on 2024-04-12 of 3 shares at 105.53.
# Updated Quantity: 3, Updated Avg Cost: 105.53 (Previous Avg Cost: 0.00)
#
# Purchase on 2024-09-02 of 4 shares at 77.55.
# Updated Quantity: 7, Updated Avg Cost: 89.54 (Previous Avg Cost: 105.53)
#
# Purchase on 2024-10-28 of 7 shares at 53.65.
# Updated Quantity: 14, Updated Avg Cost: 71.60 (Previous Avg Cost: 89.54)
#
# Purchase on 2024-10-28 of 6 shares at 42.35.
# Updated Quantity: 20, Updated Avg Cost: 62.82 (Previous Avg Cost: 71.60)
#
# Purchase on 2025-01-14 of 10 shares at 35.20.
# Updated Quantity: 30, Updated Avg Cost: 53.61 (Previous Avg Cost: 62.82)
#
# Purchase on 2025-02-13 of 10 shares at 31.58.
# Updated Quantity: 40, Updated Avg Cost: 48.11 (Previous Avg Cost: 53.61)
#
# Processing ASML:
# Purchase on 2024-12-02 of 1 shares at 683.90.
# Updated Quantity: 1, Updated Avg Cost: 683.90 (Previous Avg Cost: 0.00)
#
# Processing VICI:
# Purchase on 2025-01-23 of 20 shares at 29.18.
# Updated Quantity: 20, Updated Avg Cost: 29.18 (Previous Avg Cost: 0.00)
#
# Processing CMG:
# Purchase on 2025-02-14 of 10 shares at 57.24.
# Updated Quantity: 10, Updated Avg Cost: 57.24 (Previous Avg Cost: 0.00)
#
# Processing BLV:
# Purchase on 2016-08-05 of 3 shares at 100.87.
# Updated Quantity: 3, Updated Avg Cost: 100.87 (Previous Avg Cost: 0.00)
#
# Purchase on 2018-02-02 of 3 shares at 92.90.
# Updated Quantity: 6, Updated Avg Cost: 96.89 (Previous Avg Cost: 100.87)
#
# Purchase on 2021-03-09 of 6 shares at 98.47.
# Updated Quantity: 12, Updated Avg Cost: 97.68 (Previous Avg Cost: 96.89)
#
# Purchase on 2023-03-06 of 12 shares at 74.04.
# Updated Quantity: 24, Updated Avg Cost: 85.86 (Previous Avg Cost: 97.68)
#
# Processing SCHD:
# Purchase on 2019-01-29 of 0.61349 shares at 48.90.
# Updated Quantity: 0.61349, Updated Avg Cost: 48.90 (Previous Avg Cost: 0.00)
#
# Purchase on 2019-06-18 of 0.47046 shares at 53.14.
# Updated Quantity: 1.08395, Updated Avg Cost: 50.74 (Previous Avg Cost: 48.90)
#
# Purchase on 2021-03-09 of 0.07048 shares at 70.95.
# Updated Quantity: 1.15443, Updated Avg Cost: 51.97 (Previous Avg Cost: 50.74)
#
# Purchase on 2021-03-16 of 0.0694 shares at 72.05.
# Updated Quantity: 1.22383, Updated Avg Cost: 53.11 (Previous Avg Cost: 51.97)
#
# Purchase on 2021-03-23 of 0.07013 shares at 71.30.
# Updated Quantity: 1.29396, Updated Avg Cost: 54.10 (Previous Avg Cost: 53.11)
#
# Purchase on 2021-03-30 of 0.06838 shares at 73.12.
# Updated Quantity: 1.36234, Updated Avg Cost: 55.05 (Previous Avg Cost: 54.10)
#
# Stock Split on 2024-10-11: Ratio 3.0.
# Previous Quantity: 1.36234, Previous Avg Cost: 55.05
# Updated Quantity: 4.087020000000001, Updated Avg Cost: 18.35
#
# Processing VB:
# Purchase on 2023-01-04 of 4 shares at 185.98.
# Updated Quantity: 4, Updated Avg Cost: 185.98 (Previous Avg Cost: 0.00)
#
# Purchase on 2023-03-06 of 3 shares at 201.37.
# Updated Quantity: 7, Updated Avg Cost: 192.58 (Previous Avg Cost: 185.98)
#
# Purchase on 2023-05-04 of 3 shares at 182.94.
# Updated Quantity: 10, Updated Avg Cost: 189.69 (Previous Avg Cost: 192.58)
#
# Purchase on 2023-06-05 of 3 shares at 190.11.
# Updated Quantity: 13, Updated Avg Cost: 189.78 (Previous Avg Cost: 189.69)
#
# Purchase on 2024-04-05 of 3 shares at 221.81.
# Updated Quantity: 16, Updated Avg Cost: 195.79 (Previous Avg Cost: 189.78)
#
# Purchase on 2024-08-05 of 1 shares at 331.13.
# Updated Quantity: 17, Updated Avg Cost: 203.75 (Previous Avg Cost: 195.79)
#
# Processing VEA:
# Purchase on 2016-08-04 of 28 shares at 36.79.
# Updated Quantity: 28, Updated Avg Cost: 36.79 (Previous Avg Cost: 0.00)
#
# Purchase on 2018-02-02 of 12 shares at 46.83.
# Updated Quantity: 40, Updated Avg Cost: 39.80 (Previous Avg Cost: 36.79)
#
# Purchase on 2020-05-01 of 15 shares at 35.05.
# Updated Quantity: 55, Updated Avg Cost: 38.51 (Previous Avg Cost: 39.80)
#
# Purchase on 2020-07-06 of 5 shares at 39.91.
# Updated Quantity: 60, Updated Avg Cost: 38.62 (Previous Avg Cost: 38.51)
#
# Purchase on 2020-08-07 of 9 shares at 40.77.
# Updated Quantity: 69, Updated Avg Cost: 38.90 (Previous Avg Cost: 38.62)
#
# Purchase on 2021-05-05 of 15 shares at 51.03.
# Updated Quantity: 84, Updated Avg Cost: 41.07 (Previous Avg Cost: 38.90)
#
# Purchase on 2021-12-06 of 20 shares at 50.20.
# Updated Quantity: 104, Updated Avg Cost: 42.82 (Previous Avg Cost: 41.07)
#
# Purchase on 2022-04-07 of 18 shares at 47.44.
# Updated Quantity: 122, Updated Avg Cost: 43.51 (Previous Avg Cost: 42.82)
#
# Processing VIG:
# Purchase on 2022-09-14 of 10 shares at 147.63.
# Updated Quantity: 10, Updated Avg Cost: 147.63 (Previous Avg Cost: 0.00)
#
# Purchase on 2022-10-10 of 4 shares at 137.39.
# Updated Quantity: 14, Updated Avg Cost: 144.70 (Previous Avg Cost: 147.63)
#
# Purchase on 2022-11-07 of 4 shares at 146.89.
# Updated Quantity: 18, Updated Avg Cost: 145.19 (Previous Avg Cost: 144.70)
#
# Purchase on 2022-12-06 of 3 shares at 156.09.
# Updated Quantity: 21, Updated Avg Cost: 146.75 (Previous Avg Cost: 145.19)
#
# Purchase on 2023-04-04 of 4 shares at 155.03.
# Updated Quantity: 25, Updated Avg Cost: 148.07 (Previous Avg Cost: 146.75)
#
# Purchase on 2024-04-05 of 5 shares at 163.28.
# Updated Quantity: 30, Updated Avg Cost: 150.61 (Previous Avg Cost: 148.07)
#
# Processing VNQ:
# Purchase on 2016-08-05 of 11 shares at 91.10.
# Updated Quantity: 11, Updated Avg Cost: 91.10 (Previous Avg Cost: 0.00)
#
# Purchase on 2017-06-28 of 10 shares at 84.90.
# Updated Quantity: 21, Updated Avg Cost: 88.15 (Previous Avg Cost: 91.10)
#
# Purchase on 2020-05-01 of 5 shares at 74.08.
# Updated Quantity: 26, Updated Avg Cost: 85.44 (Previous Avg Cost: 88.15)
#
# Purchase on 2020-07-06 of 4 shares at 81.60.
# Updated Quantity: 30, Updated Avg Cost: 84.93 (Previous Avg Cost: 85.44)
#
# Purchase on 2020-08-07 of 6 shares at 80.93.
# Updated Quantity: 36, Updated Avg Cost: 84.26 (Previous Avg Cost: 84.93)
#
# Purchase on 2021-01-04 of 8 shares at 85.20.
# Updated Quantity: 44, Updated Avg Cost: 84.43 (Previous Avg Cost: 84.26)
#
# Purchase on 2021-12-28 of 4 shares at 113.93.
# Updated Quantity: 48, Updated Avg Cost: 86.89 (Previous Avg Cost: 84.43)
#
# Purchase on 2022-07-05 of 10 shares at 91.81.
# Updated Quantity: 58, Updated Avg Cost: 87.74 (Previous Avg Cost: 86.89)
#
# Purchase on 2023-07-06 of 8 shares at 83.66.
# Updated Quantity: 66, Updated Avg Cost: 87.25 (Previous Avg Cost: 87.74)
#
#
# Purchase on 2021-08-05 of 20 shares at 51.84.
# Updated Quantity: 37, Updated Avg Cost: 45.27 (Previous Avg Cost: 37.55)
#
# Purchase on 2022-04-04 of 20 shares at 47.60.
# Updated Quantity: 57, Updated Avg Cost: 46.09 (Previous Avg Cost: 45.27)
#
# Purchase on 2024-04-05 of 18 shares at 39.64.
# Updated Quantity: 75, Updated Avg Cost: 44.54 (Previous Avg Cost: 46.09)
# /var/folders/3l/flqcxq8n6xd5d268qr1vn1_00000gn/T/ipykernel_87264/4276215736.py:143: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_stocks['Price'] = round(filtered_stocks['Price'],2)
# /var/folders/3l/flqcxq8n6xd5d268qr1vn1_00000gn/T/ipykernel_87264/4276215736.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_stocks['Quantity'] = round(filtered_stocks['Quantity'],2)
# /var/folders/3l/flqcxq8n6xd5d268qr1vn1_00000gn/T/ipykernel_87264/4276215736.py:145: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_stocks['Avg_Cost'] = round(filtered_stocks['Avg_Cost'],2)
# /var/folders/3l/flqcxq8n6xd5d268qr1vn1_00000gn/T/ipykernel_87264/4276215736.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_stocks['Market_Value'] = round(filtered_stocks['Market_Value'],2)
# /var/folders/3l/flqcxq8n6xd5d268qr1vn1_00000gn/T/ipykernel_87264/4276215736.py:147: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_stocks['Percent_Change'] = round(filtered_stocks['Percent_Change'],2)
# /var/folders/3l/flqcxq8n6xd5d268qr1vn1_00000gn/T/ipykernel_87264/4276215736.py:148: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_stocks['Equity_Change'] = round(filtered_stocks['Equity_Change'],2)
# /var/folders/3l/flqcxq8n6xd5d268qr1vn1_00000gn/T/ipykernel_87264/4276215736.py:149: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_stocks['52_Week_High'] = round(filtered_stocks['52_Week_High'],2)
# /var/folders/3l/flqcxq8n6xd5d268qr1vn1_00000gn/T/ipykernel_87264/4276215736.py:150: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_stocks['52_Week_Low'] = round(filtered_stocks['52_Week_Low'],2)

# %%
# Print out a sample
print(stock_summary_df.head(20))
# Save the df to the data folder
stock_summary_df.to_csv('data/stock_summary.csv')
# Out:
#    Stock                            Company    Price  Quantity  Avg_Cost  \
# 7   NVDA                 NVIDIA Corporation   110.93      40.0      3.23
# 14  UBER            Uber Technologies, Inc.    72.28      36.0     49.31
# 50  SPOT            Spotify Technology S.A.   543.66       4.0    124.00
# 59  MELI                 MercadoLibre, Inc.  1996.95       1.0    867.90
# 63   COF  Capital One Financial Corporation   160.97      12.0     96.17
# 47  COST       Costco Wholesale Corporation   963.41       2.0    545.19
# 12   NKE                         NIKE, Inc.    54.39      35.0     78.18
# 48  SNOW                     Snowflake Inc.   144.96      13.0    156.22
# 29   AMD       Advanced Micro Devices, Inc.    93.40      20.0    113.24
# 52    BE           Bloom Energy Corporation    17.64     100.0     13.16
# 49  DUOL                     Duolingo, Inc.   329.35       5.0     92.00
# 72  BEPC   Brookfield Renewable Corporation    26.38      60.0     24.08
# 68    VZ        Verizon Communications Inc.    43.73      35.0     36.69
# 70  CRWD         CrowdStrike Holdings, Inc.   377.90       4.0    103.52
# 60     O          Realty Income Corporation    55.22      27.0     55.69
# 75  ASML                  ASML Holding N.V.   668.81       2.0    688.22
# 21     V                          Visa Inc.   333.40       4.0    198.38
# 62  MSFT              Microsoft Corporation   388.45       3.0    254.47
# 71   LOW             Lowe's Companies, Inc.   220.35       5.0    193.32
# 74  MRNA                      Moderna, Inc.    26.20      40.0     48.11
#
#     Market_Value  Percent_Change  Equity_Change  52_Week_High  52_Week_Low  \
# 7        4437.20           28.99        4307.81        153.13        75.61
# 14       2602.08           -1.53         827.01         87.00        54.84
# 50       2174.64           87.13        1678.64        652.63       267.76
# 59       1996.95           41.04        1129.05       2374.54      1324.99
# 63       1931.64           15.66         777.57        210.67       128.23
# 47       1926.82           34.13         836.44       1078.23       702.00
# 12       1903.65          -41.58        -832.52         98.04        52.28
# 48       1884.48           -4.62        -146.35        194.40       107.13
# 29       1868.00          -41.74        -396.89        187.28        76.48
# 52       1764.00           72.27         448.22         29.82         9.02
# 49       1646.75           68.41        1186.75        441.76       145.05
# 72       1582.80           19.80         137.88         35.14        21.35
# 68       1530.55            9.03         246.53         47.36        37.59
# 70       1511.60           26.18        1097.52        455.59       200.81
# 60       1490.94            6.91         -12.65         64.88        50.65
# 75       1337.62          -29.95         -38.82       1110.09       578.51
# 21       1333.60           22.90         540.10        366.54       252.70
# 62       1165.35           -6.09         401.95        468.35       344.79
# 71       1101.75           -4.20         135.13        287.01       206.39
# 74       1048.00          -74.77        -876.24        170.47        23.15
#
#     Portfolio_Diversity Direction
# 7                  9.04        Up
# 14                 5.30      Down
# 50                 4.43        Up
# 59                 4.07        Up
# 63                 3.93        Up
# 47                 3.92        Up
# 12                 3.88      Down
# 48                 3.84      Down
# 29                 3.80      Down
# 52                 3.59        Up
# 49                 3.35        Up
# 72                 3.22        Up
# 68                 3.12        Up
# 70                 3.08        Up
# 60                 3.04        Up
# 75                 2.72      Down
# 21                 2.72        Up
# 62                 2.37      Down
# 71                 2.24      Down
# 74                 2.13      Down

# %% [markdown]
# ### Daily Stocks DF

# %%
# Create Daily Stocks df
daily_stocks_df = create_daily_stock_table(stock_dictionary)
# Print out a sample
print(daily_stocks_df.head())
# Out:
# $SPWR: possibly delisted; no timezone found
# Error fetching data for SPWR: Can only use .dt accessor with datetimelike values
# $NVTA: possibly delisted; no timezone found
# Error fetching data for NVTA: Can only use .dt accessor with datetimelike values
# $ROVR: possibly delisted; no timezone found
# Error fetching data for ROVR: Can only use .dt accessor with datetimelike values

# %%
# Save the df to the data folder
daily_stocks_df.to_csv('data/daily_stocks.csv')

# %% [markdown]
# ### Stock Info DF

# %%
# Get sample Yahoo Finance output
ticker = 'NVDA'
stock = yf.Ticker(ticker)
stock_info = stock.info
print(json.dumps(stock_info, indent=4))
# Out:
# {
#     "address1": "2788 San Tomas Expressway",
#     "city": "Santa Clara",
#     "state": "CA",
#     "zip": "95051",
#     "country": "United States",
#     "phone": "408 486 2000",
#     "website": "https://www.nvidia.com",
#     "industry": "Semiconductors",
#     "industryKey": "semiconductors",
#     "industryDisp": "Semiconductors",
#     "sector": "Technology",
#     "sectorKey": "technology",
#     "sectorDisp": "Technology",
#     "longBusinessSummary": "NVIDIA Corporation, a computing infrastructure company, provides graphics and compute and networking solutions in the United States, Singapore, Taiwan, China, Hong Kong, and internationally. The Compute & Networking segment comprises Data Center computing platforms and end-to-end networking platforms, including Quantum for InfiniBand and Spectrum for Ethernet; NVIDIA DRIVE automated-driving platform and automotive development agreements; Jetson robotics and other embedded platforms; NVIDIA AI Enterprise and other software; and DGX Cloud software and services. The Graphics segment offers GeForce GPUs for gaming and PCs, the GeForce NOW game streaming service and related infrastructure, and solutions for gaming platforms; Quadro/NVIDIA RTX GPUs for enterprise workstation graphics; virtual GPU or vGPU software for cloud-based visual and virtual computing; automotive platforms for infotainment systems; and Omniverse software for building and operating industrial AI and digital twin applications. It also customized agentic solutions designed in collaboration with NVIDIA to accelerate enterprise AI adoption. The company's products are used in gaming, professional visualization, data center, and automotive markets. It sells its products to original equipment manufacturers, original device manufacturers, system integrators and distributors, independent software vendors, cloud service providers, consumer internet companies, add-in board manufacturers, distributors, automotive manufacturers and tier-1 automotive suppliers, and other ecosystem participants. NVIDIA Corporation was incorporated in 1993 and is headquartered in Santa Clara, California.",
#     "fullTimeEmployees": 36000,
#     "companyOfficers": [
#         {
#             "maxAge": 1,
#             "name": "Mr. Jen-Hsun  Huang",
#             "age": 61,
#             "title": "Co-Founder, CEO, President & Director",
#             "yearBorn": 1963,
#             "fiscalYear": 2024,
#             "totalPay": 7491487,
#             "exercisedValue": 217327152,
#             "unexercisedValue": 0
#         },
#         {
#             "maxAge": 1,
#             "name": "Ms. Colette M. Kress",
#             "age": 57,
#             "title": "Executive VP & CFO",
#             "yearBorn": 1967,
#             "fiscalYear": 2024,
#             "totalPay": 1510765,
#             "exercisedValue": 0,
#             "unexercisedValue": 0
#         },
#         {
#             "maxAge": 1,
#             "name": "Ms. Debora  Shoquist",
#             "age": 69,
#             "title": "Executive Vice President of Operations",
#             "yearBorn": 1955,
#             "fiscalYear": 2024,
#             "totalPay": 1371266,
#             "exercisedValue": 0,
#             "unexercisedValue": 0
#         },
#         {
#             "maxAge": 1,
#             "name": "Mr. Timothy S. Teter J.D.",
#             "age": 57,
#             "title": "Executive VP, General Counsel & Secretary",
#             "yearBorn": 1967,
#             "fiscalYear": 2024,
#             "totalPay": 1360939,
#             "exercisedValue": 0,
#             "unexercisedValue": 0
#         },
#         {
#             "maxAge": 1,
#             "name": "Mr. Ajay K. Puri",
#             "age": 69,
#             "title": "Executive Vice President of Worldwide Field Operations",
#             "yearBorn": 1955,
#             "fiscalYear": 2024,
#             "totalPay": 2295097,
#             "exercisedValue": 0,
#             "unexercisedValue": 0
#         },
#         {
#             "maxAge": 1,
#             "name": "Mr. Chris A. Malachowsky",
#             "title": "Co-Founder",
#             "fiscalYear": 2024,
#             "totalPay": 320000,
#             "exercisedValue": 0,
#             "unexercisedValue": 0
#         },
#         {
#             "maxAge": 1,
#             "name": "Mr. Donald F. Robertson Jr.",
#             "age": 55,
#             "title": "VP & Chief Accounting Officer",
#             "yearBorn": 1969,
#             "fiscalYear": 2024,
#             "exercisedValue": 0,
#             "unexercisedValue": 0
#         },
#         {
#             "maxAge": 1,
#             "name": "Prof. William J. Dally Ph.D.",
#             "age": 63,
#             "title": "Chief Scientist & Senior VP of Research",
#             "yearBorn": 1961,
#             "fiscalYear": 2024,
#             "exercisedValue": 0,
#             "unexercisedValue": 0
#         },
#         {
#             "maxAge": 1,
#             "name": "Mr. Toshiya  Hari",
#             "title": "Vice President of Investor Relations & Strategic Finance",
#             "fiscalYear": 2024,
#             "exercisedValue": 0,
#             "unexercisedValue": 0
#         },
#         {
#             "maxAge": 1,
#             "name": "Ms. Mylene  Mangalindan",
#             "title": "VP of Corporate Communications",
#             "fiscalYear": 2024,
#             "exercisedValue": 0,
#             "unexercisedValue": 0
#         }
#     ],
#     "auditRisk": 9,
#     "boardRisk": 10,
#     "compensationRisk": 3,
#     "shareHolderRightsRisk": 6,
#     "overallRisk": 8,
#     "governanceEpochDate": 1743465600,
#     "compensationAsOfEpochDate": 1735603200,
#     "irWebsite": "http://phx.corporate-ir.net/phoenix.zhtml?c=116466&p=irol-IRHome",
#     "executiveTeam": [],
#     "maxAge": 86400,
#     "priceHint": 2,
#     "previousClose": 107.57,
#     "open": 108.59,
#     "dayLow": 107.48,
#     "dayHigh": 111.5499,
#     "regularMarketPreviousClose": 107.57,
#     "regularMarketOpen": 108.59,
#     "regularMarketDayLow": 107.48,
#     "regularMarketDayHigh": 111.5499,
#     "dividendRate": 0.04,
#     "dividendYield": 0.04,
#     "exDividendDate": 1741737600,
#     "payoutRatio": 0.0116,
#     "fiveYearAvgDividendYield": 0.07,
#     "beta": 1.958,
#     "trailingPE": 37.731293,
#     "forwardPE": 26.924759,
#     "volume": 310088547,
#     "regularMarketVolume": 310088547,
#     "averageVolume": 304273638,
#     "averageVolume10days": 406434030,
#     "averageDailyVolume10Day": 406434030,
#     "bid": 110.54,
#     "ask": 112.0,
#     "bidSize": 50,
#     "askSize": 1,
#     "marketCap": 2706691850240,
#     "fiftyTwoWeekLow": 75.606,
#     "fiftyTwoWeekHigh": 153.13,
#     "priceToSalesTrailing12Months": 20.74141,
#     "fiftyDayAverage": 119.073,
#     "twoHundredDayAverage": 126.51575,
#     "trailingAnnualDividendRate": 0.034,
#     "trailingAnnualDividendYield": 0.00031607327,
#     "currency": "USD",
#     "tradeable": false,
#     "enterpriseValue": 2673751883776,
#     "profitMargins": 0.55848,
#     "floatShares": 23413020000,
#     "sharesOutstanding": 24399998976,
#     "sharesShort": 234404715,
#     "sharesShortPriorMonth": 241358114,
#     "sharesShortPreviousMonthDate": 1740700800,
#     "dateShortInterest": 1743379200,
#     "sharesPercentSharesOut": 0.0095999995,
#     "heldPercentInsiders": 0.04322,
#     "heldPercentInstitutions": 0.67496,
#     "shortRatio": 0.78,
#     "shortPercentOfFloat": 0.01,
#     "impliedSharesOutstanding": 25933400064,
#     "bookValue": 3.241,
#     "priceToBook": 34.227093,
#     "lastFiscalYearEnd": 1737849600,
#     "nextFiscalYearEnd": 1769385600,
#     "mostRecentQuarter": 1737849600,
#     "earningsQuarterlyGrowth": 0.798,
#     "netIncomeToCommon": 72879996928,
#     "trailingEps": 2.94,
#     "forwardEps": 4.12,
#     "lastSplitFactor": "10:1",
#     "lastSplitDate": 1717977600,
#     "enterpriseToRevenue": 20.489,
#     "enterpriseToEbitda": 32.091,
#     "52WeekChange": 0.2898687,
#     "SandP52WeekChange": 0.059571505,
#     "lastDividendValue": 0.01,
#     "lastDividendDate": 1741737600,
#     "quoteType": "EQUITY",
#     "currentPrice": 110.93,
#     "targetHighPrice": 220.0,
#     "targetLowPrice": 115.0,
#     "targetMeanPrice": 167.77692,
#     "targetMedianPrice": 170.0,
#     "recommendationMean": 1.37097,
#     "recommendationKey": "strong_buy",
#     "numberOfAnalystOpinions": 55,
#     "totalCash": 43209998336,
#     "totalCashPerShare": 1.771,
#     "ebitda": 83316998144,
#     "totalDebt": 10270000128,
#     "quickRatio": 3.672,
#     "currentRatio": 4.44,
#     "totalRevenue": 130497003520,
#     "debtToEquity": 12.946,
#     "revenuePerShare": 5.314,
#     "returnOnAssets": 0.57417,
#     "returnOnEquity": 1.1917701,
#     "grossProfits": 97858002944,
#     "freeCashflow": 44169748480,
#     "operatingCashflow": 64089001984,
#     "earningsGrowth": 0.836,
#     "revenueGrowth": 0.779,
#     "grossMargins": 0.74988997,
#     "ebitdaMargins": 0.63846,
#     "operatingMargins": 0.61107,
#     "financialCurrency": "USD",
#     "symbol": "NVDA",
#     "language": "en-US",
#     "region": "US",
#     "typeDisp": "Equity",
#     "quoteSourceName": "Nasdaq Real Time Price",
#     "triggerable": true,
#     "customPriceAlertConfidence": "HIGH",
#     "marketState": "CLOSED",
#     "corporateActions": [],
#     "postMarketTime": 1744415999,
#     "regularMarketTime": 1744401601,
#     "exchange": "NMS",
#     "messageBoardId": "finmb_32307",
#     "exchangeTimezoneName": "America/New_York",
#     "exchangeTimezoneShortName": "EDT",
#     "gmtOffSetMilliseconds": -14400000,
#     "market": "us_market",
#     "esgPopulated": false,
#     "epsTrailingTwelveMonths": 2.94,
#     "epsForward": 4.12,
#     "epsCurrentYear": 4.52846,
#     "priceEpsCurrentYear": 24.496187,
#     "fiftyDayAverageChange": -8.142998,
#     "fiftyDayAverageChangePercent": -0.0683866,
#     "twoHundredDayAverageChange": -15.585747,
#     "twoHundredDayAverageChangePercent": -0.12319215,
#     "sourceInterval": 15,
#     "exchangeDataDelayedBy": 0,
#     "averageAnalystRating": "1.4 - Strong Buy",
#     "cryptoTradeable": false,
#     "hasPrePostMarketData": true,
#     "firstTradeDateMilliseconds": 917015400000,
#     "postMarketChangePercent": -0.198593,
#     "postMarketPrice": 110.71,
#     "postMarketChange": -0.220299,
#     "regularMarketChange": 3.3600006,
#     "regularMarketDayRange": "107.48 - 111.5499",
#     "fullExchangeName": "NasdaqGS",
#     "averageDailyVolume3Month": 304273638,
#     "fiftyTwoWeekLowChange": 35.323997,
#     "fiftyTwoWeekLowChangePercent": 0.46721154,
#     "fiftyTwoWeekRange": "75.606 - 153.13",
#     "fiftyTwoWeekHighChange": -42.200005,
#     "fiftyTwoWeekHighChangePercent": -0.27558285,
#     "fiftyTwoWeekChangePercent": 28.986872,
#     "dividendDate": 1743552000,
#     "earningsTimestamp": 1748462400,
#     "earningsTimestampStart": 1748462400,
#     "earningsTimestampEnd": 1748462400,
#     "earningsCallTimestampStart": 1740607200,
#     "earningsCallTimestampEnd": 1740607200,
#     "isEarningsDateEstimate": false,
#     "regularMarketChangePercent": 3.123548,
#     "regularMarketPrice": 110.93,
#     "shortName": "NVIDIA Corporation",
#     "longName": "NVIDIA Corporation",
#     "displayName": "NVIDIA",
#     "trailingPegRatio": 1.0801
# }

# %%
# Fetch the list of Nasdaq tickers
nasdaq_tickers = fetch_nasdaq_tickers()
# print(nasdaq_tickers)

# Fetch the list of SP500 tickers
sp500_tickers = fetch_sp500_tickers()
# print(sp500_tickers)

# Combine all tickers into a set to remove duplicates
unique_stock_tickers = list(set(sp500_tickers + nasdaq_tickers))

# %%
nasdaq_tickers = set(fetch_nasdaq_tickers())  # Convert list to set
sp500_tickers = set(fetch_sp500_tickers())  # Convert list to set

# Find overlap
sp500_in_nasdaq = sp500_tickers.intersection(nasdaq_tickers)
sp500_not_in_nasdaq = sp500_tickers - nasdaq_tickers

# Print results
print(f"Total S&P 500 Tickers: {len(sp500_tickers)}")
print(f"Total Nasdaq Tickers: {len(nasdaq_tickers)}")
print(f"Number of S&P 500 companies also in Nasdaq: {len(sp500_in_nasdaq)}")
print(f"Number of S&P 500 companies NOT in Nasdaq: {len(sp500_not_in_nasdaq)}")
# Out:
# Total S&P 500 Tickers: 503
# Total Nasdaq Tickers: 4840
# Number of S&P 500 companies also in Nasdaq: 156
# Number of S&P 500 companies NOT in Nasdaq: 347

# %%
# Create Stock Info df
stock_info_df = create_stock_info_table(unique_stock_tickers, limit=1000)
# Print out a sample
print(stock_info_df.head())
# Out:
# [1/1000] Fetching data for: KC
# [2/1000] Fetching data for: LFUS
# [3/1000] Fetching data for: HQY
# [4/1000] Fetching data for: NVNO
# [5/1000] Fetching data for: MMC
# [6/1000] Fetching data for: FTCI
# [7/1000] Fetching data for: HKIT
# [8/1000] Fetching data for: BUFM
# [9/1000] Fetching data for: UMBFP
# [10/1000] Fetching data for: PRME
# [11/1000] Fetching data for: RPTX
# [12/1000] Fetching data for: YSPY
# [13/1000] Fetching data for: PBPB
# [14/1000] Fetching data for: AAPD
# [15/1000] Fetching data for: PFX
# [16/1000] Fetching data for: NVDL
# [17/1000] Fetching data for: VXUS
# [832/1000] Fetching data for: TYRA
# [833/1000] Fetching data for: OST
# [834/1000] Fetching data for: OTLY
# [835/1000] Fetching data for: CPZ
# [836/1000] Fetching data for: EFSC
# [837/1000] Fetching data for: MKTW
# [838/1000] Fetching data for: SVIIU
# [839/1000] Fetching data for: SFM
# [840/1000] Fetching data for: VLGEA
# [841/1000] Fetching data for: SEATW
# [842/1000] Fetching data for: BLUE
# [843/1000] Fetching data for: PRTG
# [844/1000] Fetching data for: HCOW
# [845/1000] Fetching data for: OKYO
# [846/1000] Fetching data for: TENB
# [847/1000] Fetching data for: TRI
# [848/1000] Fetching data for: OBT
# [849/1000] Fetching data for: SSBI
# [850/1000] Fetching data for: FLX
# [851/1000] Fetching data for: GMGI
# [852/1000] Fetching data for: NSCR
# [853/1000] Fetching data for: AIFEU
# [854/1000] Fetching data for: ACNT
# [855/1000] Fetching data for: INSM
# [856/1000] Fetching data for: BTMWW
# [857/1000] Fetching data for: ARAY
# [858/1000] Fetching data for: SPKLU
# [859/1000] Fetching data for: AIRTP
# [860/1000] Fetching data for: HWC

# %%
# Save the df to the data folder
stock_info_df.to_csv('data/stock_info.csv')

# %% [markdown]
# ### Create Final Tables by merging and cleaning dfs

# %%
## Create a lookup table for Stock Tickers to Company Names
stock_names = stock_summary_df[['Stock', 'Company']]

# %%
## Merge stocks and stocks_info
stocks_complete = pd.merge(stock_summary_df, stock_info_df, how = 'left', on = 'Stock')

# %%
## Merge daily_stocks and stock_names
daily_stocks_complete = pd.merge(daily_stocks_df, stock_names)
# Create datetime column
daily_stocks_complete['Datetime'] = pd.to_datetime(daily_stocks_complete['Date'])

# %%
## Create a dataframe with daily total equity
daily_equity = daily_stocks_complete.groupby(by=["Date"])[["Market_Value", "Equity", "Total_Profit"]].sum()
daily_equity = daily_equity.reset_index()
# Set Date column as datetime
daily_equity['Date'] = pd.to_datetime(daily_equity['Date'])
# Create Daily_Profit column
daily_equity['Daily_Profit'] = daily_equity['Total_Profit'].diff()
# Format Daily_Profit columns
daily_equity['Daily_Profit'] = round(daily_equity['Daily_Profit'], 2)
# Remove unnamed columns
daily_equity = daily_equity.loc[:, ~daily_equity.columns.str.contains('^Unnamed')]

# %%
## Create Daily Gainers / Losers dataframes
most_recent_date = daily_stocks_complete['Datetime'].max()
todays_stocks = daily_stocks_complete[(daily_stocks_complete['Datetime'] == most_recent_date) &
                                      (daily_stocks_complete['Shares_Held'] != 0) &
                                      (daily_stocks_complete['Company'] != "0")].copy()
daily_gainers = todays_stocks[['Company', 'Daily_Profit', 'Daily_Pct_Profit']].reset_index(drop=True).sort_values("Daily_Profit", axis = 0, ascending = False).head(5)
daily_losers = todays_stocks[['Company', 'Daily_Profit', 'Daily_Pct_Profit']].reset_index(drop=True).sort_values("Daily_Profit", axis = 0, ascending = True).head(5)
# Remove any negatives from gainers and positives from losers
daily_gainers = daily_gainers[daily_gainers['Daily_Profit'] > 0]
daily_losers = daily_losers[daily_losers['Daily_Profit'] < 0]
# Format dataframe values
daily_gainers['Daily_Profit'] = daily_gainers['Daily_Profit'].apply(lambda x: "${:,.2f}".format(x))
daily_gainers['Daily_Pct_Profit'] = daily_gainers['Daily_Pct_Profit'].apply(lambda x: "{:.2f}%".format(x))
daily_losers['Daily_Profit'] = daily_losers['Daily_Profit'].apply(lambda x: "${:,.2f}".format(x))
daily_losers['Daily_Pct_Profit'] = daily_losers['Daily_Pct_Profit'].apply(lambda x: "{:.2f}%".format(x))

# %% [markdown]
# ## Buying Opportunities

# %% [markdown]
# I also want to have a smarter way to re-buy into stocks that I currently own. To do this, I will create a "buy score", which will consist of the following 4 criteria:
#
# - % of total portfolio (Value based on ranked position)
# - stock's industry representation (Value based on ranked position)
# - 52-week high low value (the lower in the 52 week high low, the higher the score)
# - Yahoo Finance price target and buy recommendation
#
# Each category will get a value assigned between 0-25 according to its position in the range of value. This will be done by comparing the value to the maximum and minumum for the category to compute its relative position. The resulting value will then get scaled to the 0-25 scale and the scores from each category will then be summed to create a final "buy score". By comparing the buy scores across all stocks, we can see which are the best opportunities to deploy our available money.

# %%
# Calculate how much a stock is trading below its target price
stocks_complete["Target_Discount"] = (
    (stocks_complete["Target_Mean_Price"] - stocks_complete["Price"]) / stocks_complete["Target_Mean_Price"]
)
 # Ensure it's between 0-100%
stocks_complete["Target_Discount"] = stocks_complete["Target_Discount"].clip(0, 1)

# %%
# Fetch VIX (Fear Index)
vix = yf.Ticker("^VIX").history(period="1mo")["Close"].iloc[-1]

# Fetch S&P 500 performance (30 days)
sp500 = yf.Ticker("^GSPC").history(period="1mo")
sp500_performance = (sp500["Close"].iloc[-1] - sp500["Close"].iloc[0]) / sp500["Close"].iloc[0]

# Assign Market Sentiment Score (Inverse relationship)
market_sentiment_score = (vix / 40) + (1 - sp500_performance)  # Higher VIX and lower SP500 → higher score
market_sentiment_score = np.clip(market_sentiment_score, 0, 1)

# Add this market sentiment score as a new columns
stocks_complete["Market_Sentiment_Score"] = market_sentiment_score

# %%
# Rank certain categories within their industry for better comparison
for col in ['Profit_Margins', 'Return_On_Equity', 'Return_On_Assets']:
    stocks_complete = rank_within_industry(stocks_complete, col)

# %%
stocks_complete.columns

# %%
# Create the buying score based off these key metrics
stocks_complete["Buying_Score"] = (
    stocks_complete["Target_Discount"] * 0.20 +  # Undervaluation vs Target Price
    stocks_complete["Profit_Margins_Rank"] * 0.15 +  # Profitability within Industry
    stocks_complete["Return_On_Equity_Rank"] * 0.15 +  # ROE within Industry
    stocks_complete["Return_On_Assets_Rank"] * 0.10 +  # ROA within Industry
    ((stocks_complete["52_Week_High"] - stocks_complete["Price"]) / (stocks_complete["52_Week_High"] - stocks_complete["52_Week_Low"])) * 0.10 +  # 52-Week Lows
    ((1 - stocks_complete["Portfolio_Diversity"]) * 0.15) +  # Portfolio Balancing (Invest in underweighted stocks)
    stocks_complete["Market_Sentiment_Score"] * 0.15  # Buy more when market is fearful
)
# Rank the stocks by their buying score
stocks_complete["Rank"] = stocks_complete["Buying_Score"].rank(ascending=False, method="min")
# Display the top results
top_opportunities = stocks_complete.sort_values("Buying_Score", ascending=False).head(20)

# %%
top_opportunities
